# %%
import sys, os
sys.path.append("..")
import numpy as np
# import matplotlib.pyplot as plt
import common as com
import sys as sys
import os as os
import fisher_plot as fsh
import matplotlib.pyplot as plt
from tqdm import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
plots_dir = "./plots_NuLSSTS4/"
os.system('mkdir -p '+plots_dir)

# %%
param_och2 = """
#Cosmological parameters
[och2]
#Fiducial value
x= 0.1197
#Increment used for numerical derivatives
dx= 0.001
#Set to 'no' if this parameter should be keep fixed
is_free= yes
onesided=0

"""

param_obh2 = """
[obh2]
x= 0.02222
dx= 0.0001
is_free= yes
onesided=0

"""

param_ok = """
[ok]
x= 0.0
dx= 0.015
is_free= yes
onesided=0

"""

param_hh = """
[hh]
x= 0.69
dx= 0.01
is_free= yes
onesided=0

"""

param_w0 = """
[w0]
x= -1.0
dx= 0.01
is_free= yes
onesided=0

"""

param_wa = """
[wa]
x=0.0
dx=0.05
is_free= yes
onesided=0

"""

param_As = """
[A_s]
x= 2.1955
dx= 0.01
is_free= yes
onesided=0

"""

param_ns = """
[ns]
x= 0.9655
dx= 0.005
is_free= yes
onesided=0

"""

param_tau = """
[tau]
x=0.06
dx=0.02
is_free= yes
onesided = 0

"""

param_rt = """
[rt]
x=0.00
dx=0.005
is_free= no
onesided = 1

"""

param_mnu = """
[mnu]
x=60.
dx=10.
is_free= yes
onesided = 0

"""

param_pan = """
[pan]
x=0.
dx=0.02
is_free= no
onesided = 1

"""

param_lmcb = """
[lmcb]
x=14.08
dx=0.3
is_free= yes
onesided = 0

"""

param_etab = """
[etab]
x=0.5
dx=0.1
is_free= yes
onesided = 0

"""

tracer_cmb_primary_nos4 = """
[Tracer 1]
tracer_name= CMB_exp
tracer_type= cmb_primary
#Has temperature?
has_t= yes
#Has polarization?
has_p= yes
#Noise level in temperature in units of uK-arcmin in the two ell regimes
sigma_t= 31.13 31.13
#Noise level in polarization in units of uK-arcmin in the two ell regimes
sigma_p= 200.94 56.9402
#Beam size in units of arcmin in the two ell regimes
beam_amin= 10.0 7.0 
#Ell value that marks the transition
l_transition= 50
#Minimum ell
lmin= 2
#Maximum ell
lmax= 3000 
use_tracer= yes

"""

tracer_cmb_primary_cv = """
[Tracer 1]
tracer_name= CMB_exp
tracer_type= cmb_primary
#Has temperature?
has_t= yes
#Has polarization?
has_p= yes
#Noise level in temperature in units of uK-arcmin in the two ell regimes
sigma_t= 31.13 1.0
#Noise level in polarization in units of uK-arcmin in the two ell regimes
sigma_p= 4.0 1.4
#Beam size in units of arcmin in the two ell regimes
beam_amin= 1.6 3.0 
#Ell value that marks the transition
l_transition= 50
#Minimum ell
lmin= 2
#Maximum ell
lmax= 3000 
use_tracer= yes

"""

tracer_cmb_primary = """
[Tracer 1]
tracer_name= CMB_exp
tracer_type= cmb_primary
#Has temperature?
has_t= yes
#Has polarization?
has_p= yes
#Noise level in temperature in units of uK-arcmin in the two ell regimes
sigma_t= 31.13 1.0
#Noise level in polarization in units of uK-arcmin in the two ell regimes
sigma_p= 150.0 1.4
#Beam size in units of arcmin in the two ell regimes
beam_amin= 10.0 3.0 
#Ell value that marks the transition
l_transition= 50
#Minimum ell
lmin= 2
#Maximum ell
lmax= 3000 
use_tracer= yes

"""

tracer_cmb_lensing = """
[Tracer 2]
tracer_name= CMB_exp_lensing
tracer_type= cmb_lensing
#Noise level in temperature in units of uK-arcmin (implicitly scaled by sqrt(2) in polarization)
sigma_t= 1.0
#Beam size in units of arcmin
beam_amin= 3.0
lmin= 30
lmax= 3000
use_tracer= yes

"""

tracer_lensing = """
[Tracer 3]
tracer_name= LSST_gold_sh
tracer_type= gal_shear
bins_file= ../curves_LSST/bins_gold.txt
nz_file= ../curves_LSST/nz_shear_fiducial.txt
abias_file= ../curves_LSST/az_gold_new.txt
rfrac_file= ../curves_LSST/rf_new.txt
sigma_gamma= 0.28
include_m_bias= yes
m_step = 0.005
use_tracer= yes

"""

tracer_clustering_blue = """
[Tracer 4]
tracer_name= LSST_blue_cl
tracer_type= gal_clustering
bins_file= ../curves_LSST/bins_blue.txt
nz_file= ../curves_LSST/nz_blue.txt
bias_file= ../curves_LSST/bz_blue.txt
sbias_file= ../curves_LSST/sz_blue.txt
ebias_file= ../curves_LSST/ez_blue.txt
use_tracer= yes

"""

tracer_clustering_red = """
[Tracer 5]
tracer_name= LSST_red_cl
tracer_type= gal_clustering
bins_file= ../curves_LSST/bins_red.txt
nz_file= ../curves_LSST/nz_red.txt
bias_file= ../curves_LSST/bz_red.txt
sbias_file= ../curves_LSST/sz_red.txt
ebias_file= ../curves_LSST/ez_red.txt
use_tracer= yes

"""

tracer_bao = """
[BAO 1]
# Absolute errors on dV, dA, H
#fname_dv=../curves_DESI/DESI_sigma_dV.txt
fname_da=../curves_DESI/DESI_sigma_dA.txt
fname_hh=../curves_DESI/DESI_sigma_H.txt
#use_relative_errors = yes

"""

class_params = """
[CLASS parameters]
lmax_cmb= 5000
lmax_lss= 5000
lmin_limber= 200
include_alignment= yes
include_rsd= yes
include_magnification= no
include_gr_vel= no
include_gr_pot= no
exec_path=./run_class.sh
use_nonlinear= yes
use_baryons= yes
f_sky= 0.4

"""

output_params = """
[Output parameters]
output_dir= ../outputs_LSST_DESI_lmax5000_IAFix/
output_spectra= run
output_fisher= Fisher

[Behaviour parameters]
model= wCDM
save_cl_files= yes
save_param_files= yes

"""

# %%
def get_ini(setup = "fid", desi=False, shear=True, red=False, blue=True, ok=True, w=True, m_bias=True, vary_baryons=True, photoz=True, shear_lmax5000=True, IA_marg=True, sigma_t=1.0):
    """ Get param.ini file for a given spec as defined in the args
    """
    
    param_ini = (param_och2 + param_obh2 + param_ok +
        param_hh + param_w0 + param_wa + 
        param_As + param_ns + param_tau + 
        param_rt + param_mnu + param_pan 
        )
    
    param_ini += (param_lmcb + param_etab).replace("is_free= yes", "is_free= yes" if vary_baryons else "is_free= no")

    tcl = tracer_cmb_lensing.replace("sigma_t= 1.0", "sigma_t= " +str(sigma_t))
    
    
    if setup == "fid":
        tracers_ini = tcl + tracer_cmb_primary
    elif setup == "nos4":
        tracers_ini = tcl.replace("use_tracer= yes", "use_tracer= no") + tracer_cmb_primary_nos4
    elif setup == "cv":
        tracers_ini = tcl + tracer_cmb_primary_cv
    elif setup == "cvnos4":
        tracers_ini = tcl.replace("use_tracer= yes", "use_tracer= no") + tracer_cmb_primary_cv
    elif setup == "nocmb":
        tracers_ini = tcl.replace("use_tracer= yes", "use_tracer= no") + tracer_cmb_primary_nos4.replace("use_tracer= yes", "use_tracer= no")


    if desi: tracers_ini += tracer_bao
    tracers_ini += tracer_lensing.replace("use_tracer= yes", "use_tracer= yes" if shear else "use_tracer= no").replace("include_m_bias= yes", "include_m_bias= yes" if m_bias else "include_m_bias= no").replace("bins_gold.txt", "bins_gold.txt" if shear_lmax5000 else "bins_gold_lmax2000.txt").replace("az_gold_new.txt", "az_gold_new.txt" if IA_marg else "az_gold_new_nomarg.txt")
    tracers_ini += tracer_clustering_red.replace("use_tracer= yes", "use_tracer= yes" if red else "use_tracer= no").replace("bins_red.txt", "bins_red.txt" if photoz else "bins_red_nomarg.txt")
    tracers_ini += tracer_clustering_blue.replace("use_tracer= yes", "use_tracer= yes" if blue else "use_tracer= no").replace("bins_blue.txt", "bins_blue.txt" if photoz else "bins_blue_nomarg.txt")
    tracers_ini += param_ok.replace("is_free= yes", "is_free= yes" if ok else "is_free= no")
    tracers_ini += (param_w0 + param_wa).replace("is_free= yes", "is_free= yes" if w else "is_free= no")
    

    ini_file = param_ini + tracers_ini + class_params + output_params.replace("Fisher", "FisherDellaIAFixed_"+str(setup)+str(desi)+str(shear)+str(red)+str(blue)+str(ok)+str(w)+str(m_bias)+str(vary_baryons)+str(photoz) +str(shear_lmax5000)+str(IA_marg)+str(sigma_t))
    ini_name = "paramFixed_"+str(setup)+str(desi)+str(shear)+str(red)+str(blue)+str(ok)+str(w)+str(m_bias)+str(vary_baryons) +str(photoz) +str(shear_lmax5000)+str(IA_marg)+str(sigma_t)+".ini"    

   
    return ini_file, ini_name

# %% [markdown]
# ## $\sigma_t$ check

# %%
parlist = []
parnames = []

for sigma_t in [1.0, 2, 4, 7, 10]:

    fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True, sigma_t=sigma_t)
    parlist.append(fname)
    parnames.append("Marginalize over baryons")
    f=open(fname, "w")
    f.write(fstr)
    f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test_wok = []



for i in tqdm_notebook(range(len(parlist))):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test_wok.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue2
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue4
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue7
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue10
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 5.8331E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.3017E+01(m) +- 1.3295E+00(f)
#  - och2 = 1.1970E-01 +- 3.4296E-04(m) +- 3.3814E-05(f)
#  - hh = 6.9000E-01 +- 1.8416E-03(m) +- 1.5935E-04(f)
#  - obh2 = 2.2220E-02 +- 2.9988E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.7416E-03(m) +- 4.0239E-04(f)
#  - A_s = 2.1955E+00 +- 2.3215E-02(m) +- 1.0132E-03(f)
#  - lmcb = 1.4080E+01 +- 3.7074E-02(m) +- 1.1292E-02(f)
#  - etab = 5.0000E-01 +- 1.3338E-02(m) +- 5.4281E-03(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.6197E-01(m) +- 1.1559E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.8006E-01(m) +- 1.4047E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.4981E-01(m) +- 2.8693E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.1844E+00(m) +- 1.0511E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.0930E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0692E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2321E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.5002E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.4195E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2704E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2199E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.1822E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.0744E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 8.6636E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5143E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.2939E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8621E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4872E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.0289E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.0963E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.2880E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.2714E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.5042E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.8178E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.3777E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5924E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6182E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.0685E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.3871E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.0724E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.3617E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5067E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1497E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0506E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1187E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.3660E-03(m) +- 1.3057E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
# ../tracers.py:679: RuntimeWarning: invalid value encountered in divide
#   cos2phi = np.nan_to_num(2 * ((Ldotl1 - l**2) / (l * l2))**2 - 1.)
# ../tracers.py:701: RuntimeWarning: invalid value encountered in divide
#   cosphi = np.nan_to_num((Ldotl1 - l**2) / (l * l2))
# ../tracers.py:718: RuntimeWarning: invalid value encountered in divide
#   cos2phi = np.nan_to_num(2. * ((Ldotl1 - l**2) / (l * l2))**2 - 1.)
# ../tracers.py:750: RuntimeWarning: invalid value encountered in divide
#   cosphi =np.nan_to_num( (Ldotl1 - l**2) / (l * l2) )
#    LSST_gold_sh
# /group/hepheno/heptools/anaconda3/envs/venv_py27/lib/python2.7/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#
-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.8183E-03(m) +- 1.2564E-03(f)
#  - m0 = 0.0+- 8.0704E-02(m) +- 8.0305E-02(f)
#  - m1 = 0.0+- 1.3912E-02(m) +- 1.3095E-02(f)
#  - m2 = 0.0+- 5.1196E-03(m) +- 4.3290E-03(f)
#  - m3 = 0.0+- 2.4033E-03(m) +- 2.1369E-03(f)
#  - m4 = 0.0+- 1.5235E-03(m) +- 1.3718E-03(f)
#  - m5 = 0.0+- 1.1553E-03(m) +- 1.0761E-03(f)
#  - m6 = 0.0+- 1.0654E-03(m) +- 9.9759E-04(f)
#  - m7 = 0.0+- 1.1557E-03(m) +- 1.0741E-03(f)
#  - m8 = 0.0+- 1.4376E-03(m) +- 1.3292E-03(f)

# %%
mnu = [doc['mnu'] for doc in dict_test_wok]

# %%
st=np.array([1.,2.,4.,7.,10.])
# mnu=np.array([27.00,28.66,31.62,35.58,38.79])
# w0=np.array([0.089,0.0892,0.0901,0.0907,0.0910])
# wa=np.array([0.23,0.234,0.238,0.243,0.246])
# ok=np.array([0.000487,0.000488,0.000489,0.000490,0.000491])

plt.figure(); ax=plt.gca();
ax.plot(st,mnu/mnu[0],'-',lw=2,color='#8BB8EC',label='$\\Sigma m_\\nu$')
# ax.plot(st, w0/w0[0] ,'-',lw=2,color='#9C2121',label='$w_0$')
# ax.plot(st, wa/wa[0] ,'-',lw=2,color='#128D1E',label='$w_a$')
# ax.plot(st, ok/ok[0] ,'-',lw=2,color='#FFD500',label='$\\Omega_k$')
ax.set_xlabel('$N_T\\,\\,[\\mu{\\rm K\\,arcmin}]$',fontsize=17)
ax.set_ylabel('$\\sigma(N_T)/\\sigma(1\\mu{\\rm K\\,arcmin})$',fontsize=17)
# for tick in ax.xaxis.get_major_ticks():
#     tick.label.set_fontsize(14)
# for tick in ax.yaxis.get_major_ticks():
#     tick.label.set_fontsize(14)
plt.xlim([1.,10])
plt.tight_layout()
plt.legend(loc='upper left',frameon=False,fontsize=17,ncol=2)
plt.savefig(plots_dir+'/mnu_st_nowok.pdf',bbox_inches='tight')
# plt.show()

# %%
parlist = []
parnames = []

for sigma_t in [1.0, 2, 4, 7, 10]:

    fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True, sigma_t=sigma_t)
    parlist.append(fname)
    parnames.append("Marginalize over baryons")
    f=open(fname, "w")
    f.write(fstr)
    f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test_wok = []



for i in tqdm_notebook(range(len(parlist))):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test_wok.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue2
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue4
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue7
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue10
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 5.9366E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.7082E+01(m) +- 1.3295E+00(f)
#  - och2 = 1.1970E-01 +- 4.2835E-04(m) +- 3.3814E-05(f)
#  - hh = 6.9000E-01 +- 9.7455E-03(m) +- 1.5935E-04(f)
#  - obh2 = 2.2220E-02 +- 3.0198E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.9488E-03(m) +- 4.0239E-04(f)
#  - A_s = 2.1955E+00 +- 2.3722E-02(m) +- 1.0132E-03(f)
#  - lmcb = 1.4080E+01 +- 3.9321E-02(m) +- 1.1292E-02(f)
#  - etab = 5.0000E-01 +- 1.9998E-02(m) +- 5.4281E-03(f)
#  - ok = 0.0000E+00 +- 4.8754E-04(m) +- 3.6902E-05(f)
#  - wa = 0.0000E+00 +- 2.2968E-01(m) +- 1.8073E-03(f)
#  - w0 = -1.0000E+00 +- 8.7987E-02(m) +- 4.9891E-04(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.8553E-01(m) +- 1.1559E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.9191E-01(m) +- 1.4047E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.5870E-01(m) +- 2.8693E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.2118E+00(m) +- 1.0511E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.1274E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0962E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2607E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.5592E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.5534E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2939E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2305E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.6816E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.1482E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 9.0205E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5221E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.3072E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8743E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4949E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.2619E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.9616E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.8038E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.5523E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.6843E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.9482E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.4220E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5975E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6362E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.1868E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.5251E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.5095E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.4569E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5382E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1647E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0676E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1544E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.4306E-03(m) +- 1.3057E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
# ../tracers.py:679: RuntimeWarning: invalid value encountered in divide
#   cos2phi = np.nan_to_num(2 * ((Ldotl1 - l**2) / (l * l2))**2 - 1.)
# ../tracers.py:701: RuntimeWarning: invalid value encountered in divide
#   cosphi = np.nan_to_num((Ldotl1 - l**2) / (l * l2))
# ../tracers.py:718: RuntimeWarning: invalid value encountered in divide
#   cos2phi = np.nan_to_num(2. * ((Ldotl1 - l**2) / (l * l2))**2 - 1.)
# ../tracers.py:750: RuntimeWarning: invalid value encountered in divide
#   cosphi =np.nan_to_num( (Ldotl1 - l**2) / (l * l2) )
#    LSST_gold_sh
# /group/hepheno/heptools/anaconda3/envs/venv_py27/lib/python2.7/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#
f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.8664E-01(m) +- 1.1621E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.9488E-01(m) +- 1.4275E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.6823E-01(m) +- 2.9403E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.2426E+00(m) +- 1.0787E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.1952E-02(m) +- 4.2338E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.3572E-02(m) +- 3.4182E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.6936E-02(m) +- 3.7704E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 2.3047E-02(m) +- 4.2441E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 3.4501E-02(m) +- 8.6175E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2953E-03(m) +- 1.1829E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2355E-03(m) +- 7.2404E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.7533E-04(m) +- 6.1000E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.1613E-03(m) +- 5.5578E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 9.1800E-04(m) +- 5.3134E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5931E-03(m) +- 5.4514E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.4103E-03(m) +- 5.2797E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 2.0512E-03(m) +- 5.0011E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.7668E-03(m) +- 5.2212E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.2704E-03(m) +- 1.6621E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.9810E-03(m) +- 8.4521E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.8234E-03(m) +- 7.7908E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.5755E-03(m) +- 7.5075E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.7137E-03(m) +- 7.4860E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 2.0156E-03(m) +- 7.7310E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.5467E-03(m) +- 7.8154E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.9576E-03(m) +- 8.6732E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.8198E-03(m) +- 1.2564E-03(f)
#  - m0 = 0.0+- 8.1934E-02(m) +- 8.0305E-02(f)
#  - m1 = 0.0+- 1.5297E-02(m) +- 1.3095E-02(f)
#  - m2 = 0.0+- 5.5179E-03(m) +- 4.3290E-03(f)
#  - m3 = 0.0+- 2.4627E-03(m) +- 2.1369E-03(f)
#  - m4 = 0.0+- 1.5423E-03(m) +- 1.3718E-03(f)
#  - m5 = 0.0+- 1.1699E-03(m) +- 1.0761E-03(f)
#  - m6 = 0.0+- 1.0776E-03(m) +- 9.9759E-04(f)
#  - m7 = 0.0+- 1.1723E-03(m) +- 1.0741E-03(f)
#  - m8 = 0.0+- 1.4638E-03(m) +- 1.3292E-03(f)

# %%
mnu = [doc['mnu'] for doc in dict_test_wok]
w0 = [doc['w0'] for doc in dict_test_wok]
wa = [doc['wa'] for doc in dict_test_wok]
ok = [doc['ok'] for doc in dict_test_wok]

# %%
st=np.array([1.,2.,4.,7.,10.])
# mnu=np.array([27.00,28.66,31.62,35.58,38.79])
# w0=np.array([0.089,0.0892,0.0901,0.0907,0.0910])
# wa=np.array([0.23,0.234,0.238,0.243,0.246])
# ok=np.array([0.000487,0.000488,0.000489,0.000490,0.000491])

plt.figure(); ax=plt.gca();
ax.plot(st,mnu/mnu[0],'-',lw=2,color='#8BB8EC',label='$\\Sigma m_\\nu$')
ax.plot(st, w0/w0[0] ,'-',lw=2,color='#9C2121',label='$w_0$')
ax.plot(st, wa/wa[0] ,'-',lw=2,color='#128D1E',label='$w_a$')
ax.plot(st, ok/ok[0] ,'-',lw=2,color='#FFD500',label='$\\Omega_k$')
ax.set_xlabel('$N_T\\,\\,[\\mu{\\rm K\\,arcmin}]$',fontsize=17)
ax.set_ylabel('$\\sigma(N_T)/\\sigma(1\\mu{\\rm K\\,arcmin})$',fontsize=17)
# for tick in ax.xaxis.get_major_ticks():
#     tick.label.set_fontsize(14)
# for tick in ax.yaxis.get_major_ticks():
#     tick.label.set_fontsize(14)
plt.xlim([1.,10])
plt.tight_layout()
plt.legend(loc='upper left',frameon=False,fontsize=17,ncol=2)
plt.savefig(plots_dir+'/mnu_st.pdf',bbox_inches='tight')
# plt.show()

# %% [markdown]
# # Figure 1

# %%
parlist = []
parnames = []

fstr, fname = get_ini(desi=True,shear=False,red=False,blue=False,ok=False,w=False,m_bias=False, vary_baryons=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=True,shear=False,red=False,blue=False,ok=True,w=True,m_bias=False, vary_baryons=False)
parlist.append(fname)
parnames.append("Don't marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidTrueFalseFalseFalseFalseFalseFalseFalseTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 4 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 7 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidTrueFalseFalseFalseTrueTrueFalseFalseTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 4 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 10 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Fisher forecast :
#  - tau = 6.0000E-02 +- 6.8077E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.6493E+01(m) +- 1.6969E+00(f)
#  - och2 = 1.1970E-01 +- 5.1185E-04(m) +- 4.2384E-05(f)
#  - hh = 6.9000E-01 +- 2.9142E-03(m) +- 1.6848E-04(f)
#  - obh2 = 2.2220E-02 +- 3.0645E-05(m) +- 1.2279E-05(f)
#  - ns = 9.6550E-01 +- 1.9083E-03(m) +- 4.7364E-04(f)
#  - A_s = 2.1955E+00 +- 2.7343E-02(m) +- 1.1700E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for ok
# Deriv for wa
# Deriv for w0
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on ok
# Prior is 0.0 on wa
# Prior is 0.0 on w0
# Fisher forecast :
#  - tau = 6.0000E-02 +- 7.0703E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 6.5888E+01(m) +- 1.6969E+00(f)
#  - och2 = 1.1970E-01 +- 7.2180E-04(m) +- 4.2384E-05(f)
#  - hh = 6.9000E-01 +- 1.3255E-02(m) +- 1.6848E-04(f)
#  - obh2 = 2.2220E-02 +- 3.2355E-05(m) +- 1.2279E-05(f)
#  - ns = 9.6550E-01 +- 2.2388E-03(m) +- 4.7364E-04(f)
#  - A_s = 2.1955E+00 +- 2.9484E-02(m) +- 1.1700E-03(f)
#  - ok = 0.0000E+00 +- 4.7738E-04(m) +- 3.7022E-05(f)
#  - wa = 0.0000E+00 +- 3.8530E-01(m) +- 1.9338E-03(f)
#  - w0 = -1.0000E+00 +- 1.2781E-01(m) +- 5.3090E-04(f)

# %%
label_size = 20
import matplotlib as mpl

# %%
fig=plt.figure(figsize=(5,5))
ax=fig.add_subplot(1,1,1)

cool_cols = np.array(["orange","cornflowerblue","lightcoral","goldenrod","orange","grey","chocolate","firebrick"])
mpl.rcParams['xtick.labelsize'] = label_size

labels = ['\emph{Planck}+S4+DESI','$+(w_0,w_a,\\Omega_k)$']

fsh.plot_fisher_single(pars[0].params_fshr,'mnu',[pars[i].fshr for i in range(len(pars))],ax,cool_cols,(len(pars))*[1.5],(len(pars))*["solid"],cool_cols,20,show_title=False,legend=True,labels=labels, unit="[meV]")

ax.set_xlim(0,175)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.yaxis.set_ticklabels([])
ax.legend(loc='lower left',fancybox=True,fontsize=16)


# fig=plt.figure(figsize=(4,4))
ax1=plt.axes([0.6, 0.6, .3, .3])
fsh.plot_fisher_two(pars[0].params_fshr,'mnu','och2',[pars[i].fshr for i in range(len(pars))],ax1,len(pars)*["none"],(len(pars))*[2],len(pars)*["solid"],cool_cols,3)
ax1.patch.set_alpha(0.5)

plt.tight_layout()
plt.savefig(plots_dir + "S4wok.pdf")
# Out:
# /group/hepheno/heptools/anaconda3/envs/venv_py27/lib/python2.7/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# # Table 2

# %%
parlist = []
parnames = []

fstr, fname = get_ini(desi=False,shear=False,red=False,blue=False,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=True,shear=False,red=False,blue=False,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=False,shear=False,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=False,shear=True,red=False,blue=False,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=False,shear=True,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test = []

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseFalseFalseFalseFalseFalseTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 4 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 9 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidTrueFalseFalseFalseFalseFalseTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 4 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 9 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseFalseFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 32 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseTrueFalseFalseFalseFalseTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 22 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 21 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Fisher forecast :
#  - tau = 6.0000E-02 +- 8.0283E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 7.0349E+01(m) +- 1.6971E+00(f)
#  - och2 = 1.1970E-01 +- 7.8840E-04(m) +- 4.2404E-05(f)
#  - hh = 6.9000E-01 +- 8.7771E-03(m) +- 1.6887E-04(f)
#  - obh2 = 2.2220E-02 +- 3.2785E-05(m) +- 1.2280E-05(f)
#  - ns = 9.6550E-01 +- 2.3157E-03(m) +- 4.7364E-04(f)
#  - A_s = 2.1955E+00 +- 3.4907E-02(m) +- 1.1700E-03(f)
#  - lmcb = 1.4080E+01 +- 1.0718E+00(m) +- 7.7771E-02(f)
#  - etab = 5.0000E-01 +- 3.6882E-01(m) +- 2.4012E-02(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Fisher forecast :
#  - tau = 6.0000E-02 +- 6.8487E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.7972E+01(m) +- 1.6969E+00(f)
#  - och2 = 1.1970E-01 +- 5.3969E-04(m) +- 4.2384E-05(f)
#  - hh = 6.9000E-01 +- 2.9228E-03(m) +- 1.6848E-04(f)
#  - obh2 = 2.2220E-02 +- 3.1835E-05(m) +- 1.2279E-05(f)
#  - ns = 9.6550E-01 +- 1.9358E-03(m) +- 4.7364E-04(f)
#  - A_s = 2.1955E+00 +- 2.7553E-02(m) +- 1.1700E-03(f)
#  - lmcb = 1.4080E+01 +- 1.0713E+00(m) +- 7.7771E-02(f)
#  - etab = 5.0000E-01 +- 3.6831E-01(m) +- 2.4012E-02(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# <> Computing relevant noise power spectra
#    CMB_exp
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0568E-02(m) +- 6.8072E-04(f)
#  - mnu = 6.0000E+01 +- 6.9289E+01(m) +- 3.3555E+00(f)
#  - och2 = 1.1970E-01 +- 7.6725E-04(m) +- 1.2655E-04(f)
#  - hh = 6.9000E-01 +- 7.7986E-03(m) +- 8.5883E-04(f)
#  - obh2 = 2.2220E-02 +- 1.2767E-04(m) +- 6.0595E-05(f)
#  - ns = 9.6550E-01 +- 3.6091E-03(m) +- 1.6227E-03(f)
#  - A_s = 2.1955E+00 +- 4.6321E-02(m) +- 2.2805E-03(f)
#  - lmcb = 1.4080E+01 +- 1.5305E+00(m) +- 6.9620E-01(f)
#  - etab = 5.0000E-01 +- 5.1770E-01(m) +- 2.3362E-01(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 3.8840E-02(m) +- 7.4779E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 3.9831E-02(m) +- 4.5336E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 4.7768E-02(m) +- 4.1444E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 5.5881E-02(m) +- 4.3410E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 6.9933E-02(m) +- 8.6776E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 4.5492E-03(m) +- 2.6221E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 4.0846E-03(m) +- 1.4252E-03(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 1.8197E-03(m) +- 9.4955E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 3.0088E-03(m) +- 7.4268E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 1.7773E-03(m) +- 6.2774E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 3.4471E-03(m) +- 5.8827E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.9502E-03(m) +- 5.4477E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 3.0330E-03(m) +- 5.0597E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 3.1462E-03(m) +- 5.2609E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 4.9750E-03(m) +- 3.1520E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 3.8608E-03(m) +- 1.8996E-03(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 3.9689E-03(m) +- 1.3808E-03(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +-
-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6182E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.0685E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.3871E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.0724E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.3617E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5067E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1497E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0506E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1187E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.3660E-03(m) +- 1.3057E-03(f)

# %%
parlist = []
parnames = []

fstr, fname = get_ini(desi=False,shear=False,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=True,shear=False,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()



fstr, fname = get_ini(setup="nos4", desi=False,shear=False,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
from tqdm import *

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test_wok = []



for i in tqdm_notebook(range(len(parlist))):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test_wok.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseFalseFalseFalseTrueTrueTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 4 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 12 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidTrueFalseFalseFalseTrueTrueTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 4 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 12 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseFalseFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 35 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseTrueFalseFalseTrueTrueTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 25 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 21 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on wa
# Prior is 0.0 on w0
# Fisher forecast :
#  - tau = 6.0000E-02 +- 8.3207E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 1.0559E+02(m) +- 1.6971E+00(f)
#  - och2 = 1.1970E-01 +- 7.9179E-04(m) +- 4.2404E-05(f)
#  - hh = 6.9000E-01 +- 1.6482E-01(m) +- 1.6887E-04(f)
#  - obh2 = 2.2220E-02 +- 3.4038E-05(m) +- 1.2280E-05(f)
#  - ns = 9.6550E-01 +- 2.3772E-03(m) +- 4.7364E-04(f)
#  - A_s = 2.1955E+00 +- 3.6351E-02(m) +- 1.1700E-03(f)
#  - lmcb = 1.4080E+01 +- 1.1193E+00(m) +- 7.7771E-02(f)
#  - etab = 5.0000E-01 +- 3.9638E-01(m) +- 2.4012E-02(f)
#  - ok = 0.0000E+00 +- 7.7839E-04(m) +- 3.7022E-05(f)
#  - wa = 0.0000E+00 +- 2.4571E+00(m) +- 1.9351E-03(f)
#  - w0 = -1.0000E+00 +- 1.1382E+00(m) +- 5.3150E-04(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on wa
# Prior is 0.0 on w0
# Fisher forecast :
#  - tau = 6.0000E-02 +- 7.1991E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 7.2363E+01(m) +- 1.6969E+00(f)
#  - och2 = 1.1970E-01 +- 7.2579E-04(m) +- 4.2384E-05(f)
#  - hh = 6.9000E-01 +- 1.3934E-02(m) +- 1.6848E-04(f)
#  - obh2 = 2.2220E-02 +- 3.2800E-05(m) +- 1.2279E-05(f)
#  - ns = 9.6550E-01 +- 2.3090E-03(m) +- 4.7364E-04(f)
#  - A_s = 2.1955E+00 +- 3.0227E-02(m) +- 1.1700E-03(f)
#  - lmcb = 1.4080E+01 +- 1.0737E+00(m) +- 7.7771E-02(f)
#  - etab = 5.0000E-01 +- 3.7123E-01(m) +- 2.4012E-02(f)
#  - ok = 0.0000E+00 +- 4.7749E-04(m) +- 3.7022E-05(f)
#  - wa = 0.0000E+00 +- 4.1158E-01(m) +- 1.9338E-03(f)
#  - w0 = -1.0000E+00 +- 1.3543E-01(m) +- 5.3090E-04(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# <> Computing relevant noise power spectra
#    CMB_exp
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on wa
# Prior is 0.0 on w0
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0604E-02(m) +- 6.8072E-04(f)
#  - mnu = 6.0000E+01 +- 9.1068E+01(m) +- 3.3555E+00(f)
#  - och2 = 1.1970E-01 +- 1.3881E-03(m) +- 1.2655E-04(f)
#  - hh = 6.9000E-01 +- 4.1210E-02(m) +- 8.5883E-04(f)
#  - obh2 = 2.2220E-02 +- 1.5945E-04(m) +- 6.0595E-05(f)
#  - ns = 9.6550E-01 +- 4.2698E-03(m) +- 1.6227E-03(f)
#  - A_s = 2.1955E+00 +- 4.6353E-02(m) +- 2.2805E-03(f)
#  - lmcb = 1.4080E+01 +- 1.6231E+00(m) +- 6.9620E-01(f)
#  - etab = 5.0000E-01 +- 5.2730E-01(m) +- 2.3362E-01(f)
#  - ok = 0.0000E+00 +- 3.0296E-03(m) +- 1.8482E-04(f)
#  - wa = 0.0000E+00 +- 9.6792E-01(m) +- 1.0170E-02(f)
#  - w0 = -1.0000E+00 +- 3.4483E-01(m) +- 2.8105E-03(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 5.8727E-02(m) +- 7.4779E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 5.4704E-02(m) +- 4.5336E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 5.3801E-02(m) +- 4.1444E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 5.9705E-02(m) +- 4.3410E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 7.3411E-02(m) +- 8.6776E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 5.4851E-03(m) +- 2.6221E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 4.1727E-03(m) +- 1.4252E-03(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 1.8926E-03(m) +- 9.4955E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 3.0420E-03(m) +- 7.4268E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 1.8080E-03(m) +- 6.2774E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 3.4629E-03(m) +- 5.8827E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.9632E-03(m) +- 5.4477E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 3.0368E-03(m) +- 5.0597E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 3.1476E-03(m) +- 5.2609E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +-
+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.1274E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0962E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2607E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.5592E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.5534E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2939E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2305E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.6816E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.1482E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 9.0205E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5221E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.3072E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8743E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4949E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.2619E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.9616E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.8038E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.5523E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.6843E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.9482E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.4220E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5975E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6362E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.1868E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.5251E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.5095E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.4569E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5382E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1647E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0676E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1544E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.4306E-03(m) +- 1.3057E-03(f)

# %%
title_str = ['\emph{Planck}+S4','( + DESI BAO)', 'LSST-clustering','LSST-shear','LSST-shear+clust','S4+LSST','CV+S4+LSST']

for title, dict, dict_wok in zip(title_str,dict_test, dict_test_wok):
    print title, '&', int(round(dict['mnu'],0)), '&', int(round(dict_wok['mnu'],0)), '&', round(dict_wok['ok']*1000,2), '&', round(dict_wok['w0'],2), '&', round(dict_wok['wa'],2), '\\\\'
# Out:
# \emph{Planck}+S4 & 70 & 106 & 0.78 & 1.14 & 2.46 \\
# ( + DESI BAO) & 28 & 72 & 0.48 & 0.14 & 0.41 \\
# LSST-clustering & 69 & 91 & 3.03 & 0.34 & 0.97 \\
# LSST-shear & 40 & 98 & 2.97 & 0.14 & 0.38 \\
# LSST-shear+clust & 31 & 68 & 2.05 & 0.09 & 0.27 \\
# S4+LSST & 23 & 27 & 0.49 & 0.09 & 0.23 \\

# %% [markdown]
# # Table 3

# %%
parlist = []
parnames = []


fstr, fname = get_ini(setup="nos4", desi=True,shear=False,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=True,shear=True,red=False,blue=False,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=True,shear=True,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=True,shear=True,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test = []

for i in tqdm_notebook(range(len(parlist))):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4TrueFalseFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 32 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4TrueTrueFalseFalseFalseFalseTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 22 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4TrueTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 21 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidTrueTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 45 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# <> Computing relevant noise power spectra
#    CMB_exp
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0563E-02(m) +- 6.8072E-04(f)
#  - mnu = 6.0000E+01 +- 3.5227E+01(m) +- 3.3544E+00(f)
#  - och2 = 1.1970E-01 +- 6.9015E-04(m) +- 1.2604E-04(f)
#  - hh = 6.9000E-01 +- 2.8358E-03(m) +- 8.1229E-04(f)
#  - obh2 = 2.2220E-02 +- 1.1432E-04(m) +- 6.0539E-05(f)
#  - ns = 9.6550E-01 +- 3.5409E-03(m) +- 1.6227E-03(f)
#  - A_s = 2.1955E+00 +- 4.6316E-02(m) +- 2.2805E-03(f)
#  - lmcb = 1.4080E+01 +- 1.5015E+00(m) +- 6.9620E-01(f)
#  - etab = 5.0000E-01 +- 5.1296E-01(m) +- 2.3362E-01(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 3.1016E-02(m) +- 7.4779E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 3.1564E-02(m) +- 4.5336E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 3.7201E-02(m) +- 4.1444E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 4.3465E-02(m) +- 4.3410E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 5.6112E-02(m) +- 8.6776E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 4.4146E-03(m) +- 2.6221E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 4.0658E-03(m) +- 1.4252E-03(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 1.8124E-03(m) +- 9.4955E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 3.0023E-03(m) +- 7.4268E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 1.7728E-03(m) +- 6.2774E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 3.4459E-03(m) +- 5.8827E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.9487E-03(m) +- 5.4477E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 3.0315E-03(m) +- 5.0597E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 3.1453E-03(m) +- 5.2609E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 4.9748E-03(m) +- 3.1520E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 3.8271E-03(m) +- 1.8996E-03(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 3.9687E-03(m) +- 1.3808E-03(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 3.3057E-03(m) +- 1.1000E-03(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 4.0212E-03(m) +- 9.3720E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 3.5132E-03(m) +- 8.5611E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 4.0431E-03(m) +- 8.1362E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 4.7466E-03(m) +- 8.7968E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.9663E-03(m) +- 1.2693E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    CMB_exp
#    LSST_gold_sh
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on abias_LSST_gold_sh_node1
# Prior is 0.0 on abias_LSST_gold_sh_node2
# Prior is 0.0 on abias_LSST_gold_sh_node3
# Prior is 0.0 on abias_LSST_gold_sh_node4
# Fisher forecast :
#  - tau = 6.0000E-02 +- 9.6716E-03(m) +- 6.8072E-04(f)
#  - mnu = 6.0000E+01 +- 3.1931E+01(m) +- 2.5384E+00(f)
#  - och2 = 1.1970E-01 +- 5.7531E-04(m) +- 5.7878E-05(f)
#  - hh = 6.9000E-01 +- 2.2670E-03(m) +- 4.6514E-04(f)
#  - obh2 = 2.2220E-02 +- 1.1951E-04(m) +- 5.8160E-05(f)
#  - ns = 9.6550E-01 +- 3.0702E-03(m) +- 7.3724E-04(f)
#  - A_s = 2.1955E+00 +- 3.9581E-02(m) +- 1.8856E-03(f)
#  - lmcb = 1.4080E+01 +- 5.5595E-02(m) +- 1.1674E-02(f)
#  - etab = 5.0000E-01 +- 1.5650E-02(m) +- 5.7857E-03(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +-
m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test_wok = []

for i in tqdm_notebook(range(len(parlist))):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test_wok.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4TrueFalseFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 35 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4TrueTrueFalseFalseTrueTrueTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 25 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4TrueTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 21 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidTrueTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# <> Computing relevant noise power spectra
#    CMB_exp
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on wa
# Prior is 0.0 on w0
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0598E-02(m) +- 6.8072E-04(f)
#  - mnu = 6.0000E+01 +- 8.9295E+01(m) +- 3.3544E+00(f)
#  - och2 = 1.1970E-01 +- 1.3014E-03(m) +- 1.2604E-04(f)
#  - hh = 6.9000E-01 +- 1.3881E-02(m) +- 8.1229E-04(f)
#  - obh2 = 2.2220E-02 +- 1.5810E-04(m) +- 6.0539E-05(f)
#  - ns = 9.6550E-01 +- 4.1049E-03(m) +- 1.6227E-03(f)
#  - A_s = 2.1955E+00 +- 4.6325E-02(m) +- 2.2805E-03(f)
#  - lmcb = 1.4080E+01 +- 1.5617E+00(m) +- 6.9620E-01(f)
#  - etab = 5.0000E-01 +- 5.2554E-01(m) +- 2.3362E-01(f)
#  - ok = 0.0000E+00 +- 1.6528E-03(m) +- 1.8476E-04(f)
#  - wa = 0.0000E+00 +- 4.1956E-01(m) +- 9.9860E-03(f)
#  - w0 = -1.0000E+00 +- 1.3812E-01(m) +- 2.7264E-03(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 3.5001E-02(m) +- 7.4779E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 3.8432E-02(m) +- 4.5336E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 4.5501E-02(m) +- 4.1444E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 5.4326E-02(m) +- 4.3410E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 6.9540E-02(m) +- 8.6776E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 4.5063E-03(m) +- 2.6221E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 4.0783E-03(m) +- 1.4252E-03(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 1.8291E-03(m) +- 9.4955E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 3.0048E-03(m) +- 7.4268E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 1.7799E-03(m) +- 6.2774E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 3.4474E-03(m) +- 5.8827E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.9491E-03(m) +- 5.4477E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 3.0322E-03(m) +- 5.0597E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 3.1456E-03(m) +- 5.2609E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 4.9749E-03(m) +- 3.1520E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 3.8535E-03(m) +- 1.8996E-03(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 3.9719E-03(m) +- 1.3808E-03(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 3.3134E-03(m) +- 1.1000E-03(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 4.0213E-03(m) +- 9.3720E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 3.5142E-03(m) +- 8.5611E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 4.0474E-03(m) +- 8.1362E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 4.7486E-03(m) +- 8.7968E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.9668E-03(m) +- 1.2693E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    CMB_exp
#    LSST_gold_sh
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on wa
# Prior is 0.0 on w0
# Prior is 0.0 on abias_LSST_gold_sh_node1
# Prior is 0.0 on abias_LSST_gold_sh_node2
# Prior is 0.0 on abias_LSST_gold_sh_node3
# Prior is 0.0 on abias_LSST_gold_sh_node4
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0099E-02(m) +- 6.8072E-04(f)
#  - mnu = 6.0000E+01 +- 8.2947E+01(m) +- 2.5384E+00(f)
#  - och2 = 1.1970E-01 +- 9.6876E-04(m) +- 5.7878E-05(f)
#  - hh = 6.9000E-01 +- 1.0445E-02(m) +- 4.6514E-04(f)
#  - obh2 = 2.2220E-02 +- 1.5509E-04(m) +- 5.8160E-05(f)
#  - ns = 9.6550E-01 +- 3.4159E-03(m) +- 7.3724E-04(f)
#  - A_s = 2.1955E+00 +- 4.2115E-02(m) +- 1.8856E-03(f)
#  - lmcb = 1.4080E+01 +- 7.4558E-02(m) +- 1.1674E-02(f)
#  - etab = 5.0000E-01 +- 2.3465E-02(m) +- 5.7857E-03(f)
#  - ok = 0.0000E+00 +- 1.4152E-03(m) +- 1.7305E-04(f)
#  - wa = 0.0000E+00 +- 2.9621E-01(m) +- 4.6921E-03(f)
#  - w0 = -1.0000E+00 +- 9.9205E-02(m) +- 1.3523E-03(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 2.8688E-01(m) +- 1.3906E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 3.5620E-01(m) +- 2.1381E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 8.4888E-01(m) +- 6.3192E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 7.4099E+00(m) +- 4.6159E+00(f)
#  - m0 = 0.0+- 9.7600E-02(m) +- 9.5898E-02(f)
#  - m1 = 0.0+- 1.8614E-02(m) +- 1.5118E-02(f)
#  - m2 = 0.0+- 7.9629E-03(m) +- 5.0766E-03(f)
#  - m3 = 0.0+- 3.2174E-03(m) +- 2.5394E-03(f)
#  - m4 = 0.0+- 2.1576E-03(m) +- 1.6304E-03(f)
#  - m5 = 0.0+- 1.5772E-03(m) +- 1.2729E-03(f)
#  - m6 = 0.0+- 1.5989E-03(m) +- 1.1825E-03(f)
#  - m7 = 0.0+- 1.5888E-03(m) +- 1.3213E-03(f)
#  - m8 = 0.0+- 2.5822E-03(m) +- 1.7084E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    CMB_exp
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on wa
# Prior is 0.0 on w0
# Prior is 0.0 on abias_LSST_gold_sh_node1
# Prior is 0.0 on abias_LSST_gold_sh_node2
# Prior is 0.0 on abias_LSST_gold_sh_node3
# Prior is 0.0 on abias_LSST_gold_sh_node4
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 8.6044E-03(m) +- 6.8071E-04(f)
#  - mnu = 6.0000E+01 +- 6.1984E+01(m) +- 2.0792E+00(f)
#  - och2 = 1.1970E-01 +- 8.5365E-04(m) +- 5.4011E-05(f)
#  - hh = 6.9000E-01 +- 8.3841E-03(m) +- 4.2298E-04(f)
#  - obh2 = 2.2220E-02 +- 1.4314E-04(m) +- 5.0647E-05(f)
#  - ns = 9.6550E-01 +- 3.2175E-03(m) +- 7.1407E-04(f)
#  - A_s = 2.1955E+00 +- 3.4996E-02(m) +- 1.6701E-03(f)
#  - lmcb = 1.4080E+01 +- 5.9542E-02(m) +- 1.1654E-02(f)
#  - etab = 5.0000E-01 +- 2.0615E-02(m) +- 5.7579E-03(f)
#  - ok = 0.0000E+00 +- 1.2178E-03(m) +- 1.7215E-04(f)
#  - wa = 0.0000E+00 +- 2.3712E-01(m) +- 4.5784E-03(f)
#  - w0 = -1.0000E+00 +- 7.8817E-02(m) +- 1.2968E-03(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.7943E-01(m) +- 1.1634E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.9358E-01(m) +- 1.4329E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.6900E-01(m) +- 2.9580E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.2398E+00(m) +- 1.0856E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.3478E-02(m) +- 4.2402E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1
-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8693E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4917E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.1742E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.6657E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.5919E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.4131E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.5935E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.8858E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.3988E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5960E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6323E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.1437E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.4731E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.3110E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.3850E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5101E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1561E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0626E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1428E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.4071E-03(m) +- 1.3057E-03(f)

# %%
title_str = ['LSST-clustering','LSST-shear','LSST-shear+clust','S4+LSST','CV+S4+LSST']

for title, dict, dict_wok in zip(title_str,dict_test, dict_test_wok):
    print title, '&', int(round(dict['mnu'],0)), '&', int(round(dict_wok['mnu'],0)), '&', round(dict_wok['ok']*1000,2), '&', round(dict_wok['w0'],2), '&', round(dict_wok['wa'],2), '\\\\'
# Out:
# LSST-clustering & 35 & 89 & 1.65 & 0.14 & 0.42 \\
# LSST-shear & 32 & 83 & 1.42 & 0.1 & 0.3 \\
# LSST-shear+clust & 26 & 62 & 1.22 & 0.08 & 0.24 \\
# S4+LSST & 20 & 27 & 0.45 & 0.07 & 0.19 \\

# %% [markdown]
# # Table 4

# %%
parlist = []
parnames = []


fstr, fname = get_ini(setup="cvnos4", desi=False,shear=False,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="cvnos4", desi=False,shear=True,red=False,blue=False,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="cvnos4", desi=False,shear=True,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="cv", desi=False,shear=True,red=False,blue=True,ok=False,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test = []

for i in tqdm_notebook(range(len(parlist))):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_cvnos4FalseFalseFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 32 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_cvnos4FalseTrueFalseFalseFalseFalseTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 22 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_cvnos4FalseTrueFalseTrueFalseFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   -
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on abias_LSST_gold_sh_node1
# Prior is 0.0 on abias_LSST_gold_sh_node2
# Prior is 0.0 on abias_LSST_gold_sh_node3
# Prior is 0.0 on abias_LSST_gold_sh_node4
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 2.4743E-03(m) +- 2.7582E-04(f)
#  - mnu = 6.0000E+01 +- 1.4005E+01(m) +- 1.3295E+00(f)
#  - och2 = 1.1970E-01 +- 2.2141E-04(m) +- 3.3814E-05(f)
#  - hh = 6.9000E-01 +- 1.6724E-03(m) +- 1.5935E-04(f)
#  - obh2 = 2.2220E-02 +- 2.9658E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.5224E-03(m) +- 4.0227E-04(f)
#  - A_s = 2.1955E+00 +- 1.0097E-02(m) +- 1.0132E-03(f)
#  - lmcb = 1.4080E+01 +- 3.6959E-02(m) +- 1.1292E-02(f)
#  - etab = 5.0000E-01 +- 1.3322E-02(m) +- 5.4281E-03(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.6163E-01(m) +- 1.1559E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.7997E-01(m) +- 1.4047E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.4979E-01(m) +- 2.8693E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.1842E+00(m) +- 1.0511E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.0843E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0585E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2200E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.4879E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.4128E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2704E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2197E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.1794E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.0743E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 8.6625E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5140E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.2934E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8608E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4859E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.0279E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.0912E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.2831E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.2665E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.5010E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.8168E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.3777E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5906E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6100E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.0684E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.3866E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.0670E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.3574E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5044E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1492E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0506E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1183E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.3648E-03(m) +- 1.3057E-03(f)

# %%
parlist = []
parnames = []

fstr, fname = get_ini(setup="cvnos4", desi=False,shear=False,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="cvnos4", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="cvnos4", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="cv",desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test_wok = []

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test_wok.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed
-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6271E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.1845E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.5235E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.5076E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.4560E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5361E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1632E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0673E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1543E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.4298E-03(m) +- 1.3057E-03(f)

# %%
title_str = ['LSST-clustering','LSST-shear','LSST-shear+clust','S4+LSST','CV+S4+LSST']

for title, dict, dict_wok in zip(title_str,dict_test, dict_test_wok):
    print title, '&', int(round(dict['mnu'],0)), '&', int(round(dict_wok['mnu'],0)), '&', round(dict_wok['ok']*1000,2), '&', round(dict_wok['w0'],2), '&', round(dict_wok['wa'],2), '\\\\'
# Out:
# LSST-clustering & 64 & 71 & 0.52 & 0.31 & 0.74 \\
# LSST-shear & 29 & 82 & 0.5 & 0.14 & 0.36 \\
# LSST-shear+clust & 23 & 56 & 0.49 & 0.09 & 0.25 \\
# S4+LSST & 14 & 20 & 0.49 & 0.09 & 0.23 \\

# %% [markdown]
# ## Fix $w$

# %%
parlist = []
parnames = []

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test = []

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 46 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on abias_LSST_gold_sh_node1
# Prior is 0.0 on abias_LSST_gold_sh_node2
# Prior is 0.0 on abias_LSST_gold_sh_node3
# Prior is 0.0 on abias_LSST_gold_sh_node4
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 5.8331E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.3446E+01(m) +- 1.3295E+00(f)
#  - och2 = 1.1970E-01 +- 4.2750E-04(m) +- 3.3814E-05(f)
#  - hh = 6.9000E-01 +- 1.9956E-03(m) +- 1.5935E-04(f)
#  - obh2 = 2.2220E-02 +- 3.0103E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.9469E-03(m) +- 4.0239E-04(f)
#  - A_s = 2.1955E+00 +- 2.3265E-02(m) +- 1.0132E-03(f)
#  - lmcb = 1.4080E+01 +- 3.7546E-02(m) +- 1.1292E-02(f)
#  - etab = 5.0000E-01 +- 1.3414E-02(m) +- 5.4281E-03(f)
#  - ok = 0.0000E+00 +- 4.8650E-04(m) +- 3.6902E-05(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.6199E-01(m) +- 1.1559E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.8007E-01(m) +- 1.4047E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.4983E-01(m) +- 2.8693E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.1844E+00(m) +- 1.0511E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.0933E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0710E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2363E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.5079E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.4288E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2705E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2199E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.1826E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.0744E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 8.6638E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5143E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.2939E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8621E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4872E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.0289E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.0964E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.2882E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.2719E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.5051E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.8192E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.3793E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5937E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6194E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.0685E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.3871E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.0725E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.3618E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5067E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1497E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0507E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1189E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.3665E-03(m) +- 1.3057E-03(f)

# %%
dict_test[0]['ok']*1000
# Out:
# 0.48649736136328398

# %%
dict_test[0]['mnu']
# Out:
# 23.446088772093802

# %%
parlist = []
parnames = []

fstr, fname = get_ini(desi=True,shear=True,red=False,blue=True,ok=True,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test = []

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidTrueTrueFalseTrueTrueFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 46 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on abias_LSST_gold_sh_node1
# Prior is 0.0 on abias_LSST_gold_sh_node2
# Prior is 0.0 on abias_LSST_gold_sh_node3
# Prior is 0.0 on abias_LSST_gold_sh_node4
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 5.5791E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.1842E+01(m) +- 1.3294E+00(f)
#  - och2 = 1.1970E-01 +- 4.0118E-04(m) +- 3.3804E-05(f)
#  - hh = 6.9000E-01 +- 1.5939E-03(m) +- 1.5903E-04(f)
#  - obh2 = 2.2220E-02 +- 2.9979E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.8609E-03(m) +- 4.0239E-04(f)
#  - A_s = 2.1955E+00 +- 2.2353E-02(m) +- 1.0132E-03(f)
#  - lmcb = 1.4080E+01 +- 3.7035E-02(m) +- 1.1292E-02(f)
#  - etab = 5.0000E-01 +- 1.3388E-02(m) +- 5.4281E-03(f)
#  - ok = 0.0000E+00 +- 4.3909E-04(m) +- 3.6901E-05(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.6145E-01(m) +- 1.1559E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.8003E-01(m) +- 1.4047E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.4977E-01(m) +- 2.8693E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.1837E+00(m) +- 1.0511E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.0597E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0367E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2050E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.4735E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.4011E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2703E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2181E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.1618E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.0737E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 8.6591E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5142E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.2938E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8618E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4870E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.0253E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.0791E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.2736E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.2570E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.4938E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.8115E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.3753E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5927E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6193E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.0681E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.3854E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.0529E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.3451E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.4982E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1473E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0505E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1187E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.3656E-03(m) +- 1.3057E-03(f)

# %%
dict_test[0]['ok']*1000
# Out:
# 0.43909465496768518

# %%
dict_test[0]['mnu']
# Out:
# 21.84183525333664

# %%
parlist = []
parnames = []

fstr, fname = get_ini(setup="cv",desi=False,shear=True,red=False,blue=True,ok=True,w=False,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]
dict_test = []

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
    dict_test.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_cvFalseTrueFalseTrueTrueFalseTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 46 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    CMB_exp
#    CMB_exp_lensing
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Prior is 0.0 on tau
# Prior is 0.0 on mnu
# Prior is 0.0 on och2
# Prior is 0.0 on hh
# Prior is 0.0 on obh2
# Prior is 0.0 on ns
# Prior is 0.0 on A_s
# Prior is 0.0 on lmcb
# Prior is 0.0 on etab
# Prior is 0.0 on ok
# Prior is 0.0 on abias_LSST_gold_sh_node1
# Prior is 0.0 on abias_LSST_gold_sh_node2
# Prior is 0.0 on abias_LSST_gold_sh_node3
# Prior is 0.0 on abias_LSST_gold_sh_node4
# Prior is 0.0 on bias_LSST_blue_cl_node1
# Prior is 0.0 on bias_LSST_blue_cl_node2
# Prior is 0.0 on bias_LSST_blue_cl_node3
# Prior is 0.0 on bias_LSST_blue_cl_node4
# Prior is 0.0 on bias_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node0
# Prior is 0.0 on sphz_LSST_blue_cl_node1
# Prior is 0.0 on sphz_LSST_blue_cl_node2
# Prior is 0.0 on sphz_LSST_blue_cl_node3
# Prior is 0.0 on sphz_LSST_blue_cl_node4
# Prior is 0.0 on sphz_LSST_blue_cl_node5
# Prior is 0.0 on sphz_LSST_blue_cl_node6
# Prior is 0.0 on sphz_LSST_blue_cl_node7
# Prior is 0.0 on sphz_LSST_blue_cl_node8
# Prior is 0.005 on bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Prior is 0.005 on bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Prior is 0.005 on bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Prior is 0.005 on bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Prior is 0.005 on bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Prior is 0.005 on bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Prior is 0.005 on bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Prior is 0.005 on bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Prior is 0.005 on bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 2.4759E-03(m) +- 2.7582E-04(f)
#  - mnu = 6.0000E+01 +- 1.4611E+01(m) +- 1.3295E+00(f)
#  - och2 = 1.1970E-01 +- 3.4063E-04(m) +- 3.3814E-05(f)
#  - hh = 6.9000E-01 +- 1.8460E-03(m) +- 1.5935E-04(f)
#  - obh2 = 2.2220E-02 +- 2.9775E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.7568E-03(m) +- 4.0227E-04(f)
#  - A_s = 2.1955E+00 +- 1.0166E-02(m) +- 1.0132E-03(f)
#  - lmcb = 1.4080E+01 +- 3.7419E-02(m) +- 1.1292E-02(f)
#  - etab = 5.0000E-01 +- 1.3398E-02(m) +- 5.4281E-03(f)
#  - ok = 0.0000E+00 +- 4.8601E-04(m) +- 3.6902E-05(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.6165E-01(m) +- 1.1559E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.7999E-01(m) +- 1.4047E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.4981E-01(m) +- 2.8693E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.1842E+00(m) +- 1.0511E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.0848E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0604E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2245E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.4960E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.4223E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2704E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2197E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.1798E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.0743E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 8.6627E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5140E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.2934E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8608E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4859E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.0279E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.0913E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.2834E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.2671E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.5019E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.8182E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.3793E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5918E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6111E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.0684E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.3866E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.0672E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.3575E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5045E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1492E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0507E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1185E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.3654E-03(m) +- 1.3057E-03(f)

# %%
dict_test[0]['ok']*1000
# Out:
# 0.48601465342413308

# %%
dict_test[0]['mnu']
# Out:
# 14.611240185463421

# %% [markdown]
# # Figure 2

# %%
parlist = []
parnames = []

fstr, fname = get_ini(desi=False,shear=False,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=True,shear=False,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()



fstr, fname = get_ini(setup="nos4", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=False,shear=False,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nos4", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
pars=[com.ParamRun(parname) for parname in parlist]

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseFalseFalseFalseTrueTrueTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 4 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 12 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidTrueFalseFalseFalseTrueTrueTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 4 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 12 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseTrueFalseFalseTrueTrueTrueTrueTrueTrueTrue1.0
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 25 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseFalseFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 0 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 12 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 35 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nos4FalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 21 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 8.3207E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 1.0559E+02(m) +- 1.6971E+00(f)
#  - och2 = 1.1970E-01 +- 7.9179E-04(m) +- 4.2404E-05(f)
#  - hh = 6.9000E-01 +- 1.6482E-01(m) +- 1.6887E-04(f)
#  - obh2 = 2.2220E-02 +- 3.4038E-05(m) +- 1.2280E-05(f)
#  - ns = 9.6550E-01 +- 2.3772E-03(m) +- 4.7364E-04(f)
#  - A_s = 2.1955E+00 +- 3.6351E-02(m) +- 1.1700E-03(f)
#  - lmcb = 1.4080E+01 +- 1.1193E+00(m) +- 7.7771E-02(f)
#  - etab = 5.0000E-01 +- 3.9638E-01(m) +- 2.4012E-02(f)
#  - ok = 0.0000E+00 +- 7.7839E-04(m) +- 3.7022E-05(f)
#  - wa = 0.0000E+00 +- 2.4571E+00(m) +- 1.9351E-03(f)
#  - w0 = -1.0000E+00 +- 1.1382E+00(m) +- 5.3150E-04(f)
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 7.1991E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 7.2363E+01(m) +- 1.6969E+00(f)
#  - och2 = 1.1970E-01 +- 7.2579E-04(m) +- 4.2384E-05(f)
#  - hh = 6.9000E-01 +- 1.3934E-02(m) +- 1.6848E-04(f)
#  - obh2 = 2.2220E-02 +- 3.2800E-05(m) +- 1.2279E-05(f)
#  - ns = 9.6550E-01 +- 2.3090E-03(m) +- 4.7364E-04(f)
#  - A_s = 2.1955E+00 +- 3.0227E-02(m) +- 1.1700E-03(f)
#  - lmcb = 1.4080E+01 +- 1.0737E+00(m) +- 7.7771E-02(f)
#  - etab = 5.0000E-01 +- 3.7123E-01(m) +- 2.4012E-02(f)
#  - ok = 0.0000E+00 +- 4.7749E-04(m) +- 3.7022E-05(f)
#  - wa = 0.0000E+00 +- 4.1158E-01(m) +- 1.9338E-03(f)
#  - w0 = -1.0000E+00 +- 1.3543E-01(m) +- 5.3090E-04(f)
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0281E-02(m) +- 6.8072E-04(f)
#  - mnu = 6.0000E+01 +- 9.7855E+01(m) +- 2.5389E+00(f)
#  - och2 = 1.1970E-01 +- 1.5526E-03(m) +- 5.7927E-05(f)
#  - hh = 6.9000E-01 +- 1.6335E-02(m) +- 4.7340E-04(f)
#  - obh2 = 2.2220E-02 +- 1.7227E-04(m) +- 5.8210E-05(f)
#  - ns = 9.6550E-01 +- 4.4424E-03(m) +- 7.3724E-04(f)
#  - A_s = 2.1955E+00 +- 4.4253E-02(m) +- 1.8856E-03(f)
#  - lmcb = 1.4080E+01 +- 8.7705E-02(m) +- 1.1674E-02(f)
#  - etab = 5.0000E-01 +- 2.8837E-02(m) +- 5.7857E-03(f)
#  - ok = 0.0000E+00 +- 2.9660E-03(m) +- 1.7309E-04(f)
#  - wa = 0.0000E+00 +- 3.7788E-01(m) +- 4.7107E-03(f)
#  - w0 = -1.0000E+00 +- 1.3979E-01(m) +- 1.3622E-03(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 3.0752E-01(m) +- 1.3906E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 3.7083E-01(m) +- 2.1381E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 8.6779E-01(m) +- 6.3192E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 7.4457E+00(m) +- 4.6159E+00(f)
#  - m0 = 0.0+- 9.8981E-02(m) +- 9.5898E-02(f)
#  - m1 = 0.0+- 2.0523E-02(m) +- 1.5118E-02(f)
#  - m2 = 0.0+- 8.5652E-03(m) +- 5.0766E-03(f)
#  - m3 = 0.0+- 3.3653E-03(m) +- 2.5394E-03(f)
#  - m4 = 0.0+- 2.1804E-03(m) +- 1.6304E-03(f)
#  - m5 = 0.0+- 1.5892E-03(m) +- 1.2729E-03(f)
-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.5534E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2939E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2305E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.6816E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.1482E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 9.0205E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.5221E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.3072E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8743E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4949E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.2619E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.9616E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.8038E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.5523E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.6843E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.9482E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.4220E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5975E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6362E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.1868E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.5251E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.5095E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.4569E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5382E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1647E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0676E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1544E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.4306E-03(m) +- 1.3057E-03(f)

# %%
fig=plt.figure(figsize=(5,5))
ax=fig.add_subplot(1,1,1)

cool_cols = np.array(["grey","grey","cornflowerblue","lightcoral","forestgreen","orange","grey","chocolate","firebrick"])
# mpl.rcParams['xtick.labelsize'] = label_size

labels = ['CMB S4','S4 + DESI','LSST Shear','LSST Clust','LSST Shear+Clust','S4 + LSST']

fsh.plot_fisher_single(pars[0].params_fshr,'mnu',[pars[i].fshr for i in range(len(pars))],ax,cool_cols,[1.5,1.5,1.5,1.5,1.5,2.5],["solid","dashed","solid","solid","solid","solid"],cool_cols,20,show_title=False,legend=True,labels=labels, unit='[meV]')

ax.set_xlim(0,175)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.yaxis.set_ticklabels([])
ax.legend(loc='lower left',fancybox=True,fontsize=16)

plt.tight_layout()
plt.savefig(plots_dir + "Complementarity.pdf")

# %%
# cool_cols = np.array(["grey","cornflowerblue","lightcoral","forestgreen","orange","firebrick"])

# ax = plt.axes()
fig, ax = plt.subplots(figsize=(4, 4))
fsh.plot_fisher_two(pars[0].params_fshr,"mnu","wa",[pars[i].fshr for i in range(len(pars))],ax,(len(pars))*["none"],(len(pars))*[1.5],
                           ["solid","dashed","solid","solid","solid","solid"],cool_cols,1.8,#[col_idx],
                   units=['[meV]',''], plot_2s=False)
plt.tight_layout()

plt.xlim(0,240)
plt.ylim(-2,2)

plt.savefig(plots_dir + "wamnu.pdf")

# %%
# cool_cols = np.array(["grey","cornflowerblue","lightcoral","forestgreen","orange","firebrick"])

# ax = plt.axes()
fig, ax = plt.subplots(figsize=(4, 4))
fsh.plot_fisher_two(pars[0].params_fshr,"mnu","w0",[pars[i].fshr for i in range(len(pars))],ax,(len(pars))*["none"],(len(pars))*[1.5],
                           ["solid","dashed","solid","solid","solid","solid"],cool_cols,1.8,#[col_idx],
                   units=['[meV]',''], plot_2s=False)
plt.tight_layout()
plt.xlim(0,240)
plt.ylim(-2,0)



plt.savefig(plots_dir + "w0mnu.pdf")

# %%
# cool_cols = np.array(["grey","cornflowerblue","lightcoral","forestgreen","orange","firebrick"])

# ax = plt.axes()
fig, ax = plt.subplots(figsize=(4, 4))
fsh.plot_fisher_two(pars[0].params_fshr,"mnu","ok",[pars[i].fshr for i in range(len(pars))],ax,(len(pars))*["none"],(len(pars))*[1.5],
                           ["solid","dashed","solid","solid","solid","solid"],cool_cols,1.8,#[col_idx],
                   units=['[meV]',''], plot_2s=False)
plt.tight_layout()
# plt.xlim(0,240)
# plt.ylim(-2,0)



plt.savefig(plots_dir + "okmnu.pdf")

# %% [markdown]
# ## Figure 5

# %%
class Dummy():
    def __init__(self):
        pass

# %%
new_pars = [Dummy() for _ in range(pars[0].npar_mbias)]
for i in range(len(new_pars)):
    new_pars[i].name = "m"+str(i)
    new_pars[i].do_plot = True
    new_pars[i].val = 0.
    new_pars[i].label = "$m_"+str(i)+"$"

# %%
m_params_to_plot = ["m"+str(i) for i in range(9)]

# %%
pars = np.array(pars)

# %%
zbins = np.loadtxt("../curves_LSST/bins_gold.txt", unpack=True)
z0 = zbins[0]
zf = zbins[1]
(z0+zf)/2
label1 = [str(np.round(i,3))[:4] for i in (z0+zf)/2]

# %%
mbias_list = [dict_test_wok[-1]['m'+str(i)] for i in range(9)]
mbias_fid = [0 for i in range(9)]
x = [i for i in range(9)]
x1 = np.arange(-0.5,9.,1)
label2 = ["$m_"+str(i)+"$" for i in range(9)]

# %%
label = [j for i,j in zip(label1, label2)]

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA

# %%
label1
# Out:
# ['0.08', '0.25', '0.46', '0.69', '0.97', '1.29', '1.66', '2.09', '2.59']

# %%
ax = host_subplot(111, axes_class=AA.Axes)

ax.errorbar(x, mbias_fid, yerr=mbias_list, fmt='o', capsize=10, color='purple')
ax.set_ylim(-0.02,0.02)
ax.set_xticks(x, label);
ax.set_ylabel("$\sigma(m_i)$")
ax.axhline(0, color='purple', alpha=0.2, lw=1)
# plt.yscale("log")

ax2 = ax.twin()  

ax.set_xticks(x)
ax.set_xticklabels(label)

ax2.set_xticks(np.array(x1)[::2])
ax2.set_xticklabels([str(np.abs(np.round(i,3)))[:4] for i in np.array(list(z0)+[zf[-1]])[::2]])

ax2.set_xticks(x)
ax2.set_xticklabels(label1)


ax2.axis["top"].major_ticklabels.set_visible(True)
ax2.axis["right"].major_ticklabels.set_visible(False)

ax.tick_params(axis='x', pad=2000)

ax2.set_xlabel("$z$")

for i in range(1,2):
    plt.text(i-0.3,mbias_list[i]+0.001, np.round(mbias_list[i],4), rotation=0)



for i in range(2,len(mbias_list)):
    plt.text(i-0.4,mbias_list[i]+0.001, np.round(mbias_list[i],4), rotation=0)
    
plt.axhline(0.005, ls='dotted', color='grey', label="LSST requirement")

plt.xlim(-0.6,8.6)
plt.tight_layout()
plt.legend(frameon=False, loc='lower right')
plt.savefig(plots_dir + "MultBiasS4_v2.pdf")

# %% [markdown]
# # Figure 8

# %%
parlist = []
parnames = []

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True, shear_lmax5000=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=True,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True, photoz=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=False, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True, IA_marg=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
dict_test_wok = []

pars=[com.ParamRun(parname) for parname in parlist]

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()

    dict_test_wok.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueFalseTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueTrueTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 24 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 37 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 82 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * bias_LSST_red_cl_node1 : 1.177
#     * bias_LSST_red_cl_node2 : 1.526
#     * bias_LSST_red_cl_node3 : 1.875
#     * bias_LSST_red_cl_node4 : 2.224
#     * sphz_LSST_red_cl_node0 : 0.021
#     * sphz_LSST_red_cl_node1 : 0.022
#     * sphz_LSST_red_cl_node2 : 0.023
#     * sphz_LSST_red_cl_node3 : 0.025
#     * sphz_LSST_red_cl_node4 : 0.026
#     * sphz_LSST_red_cl_node5 : 0.028
#     * sphz_LSST_red_cl_node6 : 0.030
#     * sphz_LSST_red_cl_node7 : 0.031
#     * sphz_LSST_red_cl_node8 : 0.033
#     * sphz_LSST_red_cl_node9 : 0.035
#     * sphz_LSST_red_cl_node10 : 0.038
#     * sphz_LSST_red_cl_node11 : 0.040
#     * sphz_LSST_red_cl_node12 : 0.042
#     * sphz_LSST_red_cl_node13 : 0.045
#     * sphz_LSST_red_cl_node14 : 0.048
#     * bphz_LSST_red_cl_node0 : 0.000
#     * bphz_LSST_red_cl_node1 : 0.000
#     * bphz_LSST_red_cl_node2 : 0.000
#     * bphz_LSST_red_cl_node3 : 0.000
#     * bphz_LSST_red_cl_node4 : 0.000
#     * bphz_LSST_red_cl_node5 : 0.000
#     * bphz_LSST_red_cl_node6 : 0.000
#     * bphz_LSST_red_cl_node7 : 0.000
#     * bphz_LSST_red_cl_node8 : 0.000
#     * bphz_LSST_red_cl_node9 : 0.000
#     * bphz_LSST_red_cl_node10 : 0.000
#     * bphz_LSST_red_cl_node11 : 0.000
#     * bphz_LSST_red_cl_node12 : 0.000
#     * bphz_LSST_red_cl_node13 : 0.000
#     * bphz_LSST_red_cl_node14 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTr
#  - sphz_LSST_red_cl_node10 = 3.7576E-02 +- 3.0223E-04(m) +- 1.5127E-04(f)
#  - sphz_LSST_red_cl_node11 = 3.9901E-02 +- 2.5711E-04(m) +- 1.4081E-04(f)
#  - sphz_LSST_red_cl_node12 = 4.2369E-02 +- 3.5482E-04(m) +- 1.9244E-04(f)
#  - sphz_LSST_red_cl_node13 = 4.4989E-02 +- 4.2317E-04(m) +- 2.0995E-04(f)
#  - sphz_LSST_red_cl_node14 = 4.7772E-02 +- 6.4333E-04(m) +- 2.8130E-04(f)
#  - bphz_LSST_red_cl_node0 = 0.0000E+00 +- 3.5317E-03(m) +- 1.5970E-03(f)
#  - bphz_LSST_red_cl_node1 = 0.0000E+00 +- 1.3110E-03(m) +- 5.5336E-04(f)
#  - bphz_LSST_red_cl_node2 = 0.0000E+00 +- 1.0965E-03(m) +- 4.4471E-04(f)
#  - bphz_LSST_red_cl_node3 = 0.0000E+00 +- 9.7799E-04(m) +- 2.4196E-04(f)
#  - bphz_LSST_red_cl_node4 = 0.0000E+00 +- 1.0347E-03(m) +- 2.4611E-04(f)
#  - bphz_LSST_red_cl_node5 = 0.0000E+00 +- 1.0406E-03(m) +- 2.1746E-04(f)
#  - bphz_LSST_red_cl_node6 = 0.0000E+00 +- 1.0235E-03(m) +- 1.7716E-04(f)
#  - bphz_LSST_red_cl_node7 = 0.0000E+00 +- 1.0938E-03(m) +- 2.1954E-04(f)
#  - bphz_LSST_red_cl_node8 = 0.0000E+00 +- 1.0284E-03(m) +- 1.6700E-04(f)
#  - bphz_LSST_red_cl_node9 = 0.0000E+00 +- 1.0806E-03(m) +- 1.9306E-04(f)
#  - bphz_LSST_red_cl_node10 = 0.0000E+00 +- 1.0887E-03(m) +- 1.8368E-04(f)
#  - bphz_LSST_red_cl_node11 = 0.0000E+00 +- 1.1221E-03(m) +- 1.6685E-04(f)
#  - bphz_LSST_red_cl_node12 = 0.0000E+00 +- 1.2815E-03(m) +- 2.5037E-04(f)
#  - bphz_LSST_red_cl_node13 = 0.0000E+00 +- 1.4092E-03(m) +- 3.1276E-04(f)
#  - bphz_LSST_red_cl_node14 = 0.0000E+00 +- 1.9472E-03(m) +- 5.4050E-04(f)
#  - m0 = 0.0+- 7.6473E-02(m) +- 7.5964E-02(f)
#  - m1 = 0.0+- 1.3793E-02(m) +- 1.2815E-02(f)
#  - m2 = 0.0+- 5.0376E-03(m) +- 4.2523E-03(f)
#  - m3 = 0.0+- 2.3489E-03(m) +- 2.0956E-03(f)
#  - m4 = 0.0+- 1.4777E-03(m) +- 1.3440E-03(f)
#  - m5 = 0.0+- 1.1306E-03(m) +- 1.0540E-03(f)
#  - m6 = 0.0+- 1.0474E-03(m) +- 9.7672E-04(f)
#  - m7 = 0.0+- 1.1337E-03(m) +- 1.0512E-03(f)
#  - m8 = 0.0+- 1.3976E-03(m) +- 1.2986E-03(f)
# Fisher forecast :
#  - tau = 6.0000E-02 +- 5.8736E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2
-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.6974E+01(m) +- 1.3295E+00(f)
#  - och2 = 1.1970E-01 +- 4.2562E-04(m) +- 3.3814E-05(f)
#  - hh = 6.9000E-01 +- 7.9632E-03(m) +- 1.5935E-04(f)
#  - obh2 = 2.2220E-02 +- 3.0186E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.9415E-03(m) +- 4.0239E-04(f)
#  - A_s = 2.1955E+00 +- 2.3599E-02(m) +- 1.0132E-03(f)
#  - lmcb = 1.4080E+01 +- 3.7556E-02(m) +- 1.1292E-02(f)
#  - etab = 5.0000E-01 +- 1.8698E-02(m) +- 5.4281E-03(f)
#  - ok = 0.0000E+00 +- 4.8732E-04(m) +- 3.6902E-05(f)
#  - wa = 0.0000E+00 +- 2.0282E-01(m) +- 1.8073E-03(f)
#  - w0 = -1.0000E+00 +- 7.5409E-02(m) +- 4.9891E-04(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.1139E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0910E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2373E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.5410E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.5310E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2727E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2176E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.4713E-04(m) +- 6.0943E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.0867E-03(m) +- 5.5438E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 8.4695E-04(m) +- 5.2840E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.4693E-03(m) +- 5.4068E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.2757E-03(m) +- 5.2222E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8493E-03(m) +- 4.9476E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.4804E-03(m) +- 5.1709E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.1923E-03(m) +- 1.6619E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.6589E-03(m) +- 8.4489E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.5454E-03(m) +- 7.7824E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.3557E-03(m) +- 7.4851E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.5292E-03(m) +- 7.4354E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.8025E-03(m) +- 7.6497E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.2973E-03(m) +- 7.7084E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.5468E-03(m) +- 8.5648E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.6325E-03(m) +- 1.2375E-03(f)
#  - m0 = 0.0+- 8.1667E-02(m) +- 8.0293E-02(f)
#  - m1 = 0.0+- 1.4988E-02(m) +- 1.3091E-02(f)
#  - m2 = 0.0+- 5.3311E-03(m) +- 4.3254E-03(f)
#  - m3 = 0.0+- 2.4442E-03(m) +- 2.1335E-03(f)
#  - m4 = 0.0+- 1.5164E-03(m) +- 1.3678E-03(f)
#  - m5 = 0.0+- 1.1595E-03(m) +- 1.0708E-03(f)
#  - m6 = 0.0+- 1.0641E-03(m) +- 9.8965E-04(f)
#  - m7 = 0.0+- 1.1506E-03(m) +- 1.0610E-03(f)
#  - m8 = 0.0+- 1.4229E-03(m) +- 1.3057E-03(f)

# %%
yticks = ["Fiducial", "Shear $\ell_\mathrm{max}= 2000", "Red sample", "No photo-$z$ marg.", "No baryon marg.", "No $m$-bias","No IA marg."]

# %%
# ! Send red sample improvement to David

# %%
# Simple data to display in various forms
mnu_fid =  [60 for i in range(len(dict_test_wok))]
w0_fid =  [-1 for i in range(len(dict_test_wok))]
wa_fid =  [0 for i in range(len(dict_test_wok))]
ok_fid =  [0 for i in range(len(dict_test_wok))]


x = range(len(dict_test_wok))

mnu_sys = [dict_test_wok[i]['mnu'] for i in range(len(dict_test_wok))]
w0_sys = [dict_test_wok[i]['w0'] for i in range(len(dict_test_wok))]
wa_sys = [dict_test_wok[i]['wa'] for i in range(len(dict_test_wok))]
ok_sys = [dict_test_wok[i]['ok'] for i in range(len(dict_test_wok))]




# Three subplots sharing both x/y axes
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False,figsize=(7,10))
ax1.errorbar(x, mnu_fid, yerr=mnu_sys, fmt='o', capsize=10)
ax1.set_ylim(60-40,60+40)
# ax1.set_title('Systematics')
ax1.set_ylabel("$\Sigma m_\\nu$ [meV]")
ax1.axhline(60, color='cornflowerblue', lw=0.2, ls='--')
ax1.axhline(mnu_fid[0]+mnu_sys[0], color='grey', lw=0.5, ls='dotted')
ax1.axhline(mnu_fid[0]-mnu_sys[0], color='grey', lw=0.5, ls='dotted')




ax2.errorbar(x, w0_fid, yerr=w0_sys, fmt='o', color='firebrick', capsize=10)
ax2.set_ylim(-1-0.2,-1+0.2)
ax2.set_ylabel("$w_0$")
ax2.axhline(-1, color='firebrick', lw=0.2, ls='--')
ax2.axhline(w0_fid[0]+w0_sys[0], color='grey', lw=0.5, ls='dotted')
ax2.axhline(w0_fid[0]-w0_sys[0], color='grey', lw=0.5, ls='dotted')


ax3.errorbar(x, wa_fid, yerr=wa_sys, fmt='o', color='forestgreen', capsize=10)
ax3.set_ylim(0-0.4,0+0.4)
ax3.set_ylabel("$w_a$")
ax3.axhline(0, color='forestgreen', lw=0.2, ls='--')
ax3.axhline(wa_fid[0]+wa_sys[0], color='grey', lw=0.5, ls='dotted')
ax3.axhline(wa_fid[0]-wa_sys[0], color='grey', lw=0.5, ls='dotted')




ax4.errorbar(x, ok_fid, yerr=ok_sys, fmt='o', color='darkorange', capsize=10)
ax4.set_ylim(0-0.001,0+0.001)
ax4.set_ylabel("$\Omega_k$")
ax4.axhline(0, color='darkorange', lw=0.2, ls='--')
ax4.axhline(ok_fid[0]+ok_sys[0], color='grey', lw=0.5, ls='dotted')
ax4.axhline(ok_fid[0]-ok_sys[0], color='grey', lw=0.5, ls='dotted')




ax4.set_xticks(x)
ax4.set_xticklabels(yticks, rotation=45)

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=.2)
# plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

plt.tight_layout()
plt.savefig(plots_dir + "systematics.pdf")

# %%
(w0_sys[0]-w0_sys[-1])/w0_sys[0]
# Out:
# 0.14295602059802062

# %%
(wa_sys[0]-wa_sys[-1])/wa_sys[0]
# Out:
# 0.11694069760107562

# %% [markdown]
# ## Only marg. indiv.

# %%
yticks = ["Fiducial", "No marg.", "Photo-$z$ marg.", "Baryon marg.", "$m$-bias","IA marg."]

# %%
parlist = []
parnames = []

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,photoz=True, m_bias=True, vary_baryons=True, IA_marg=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,photoz=False, m_bias=False, vary_baryons=False, IA_marg=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()



fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,photoz=True, m_bias=False, vary_baryons=False, IA_marg=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,photoz=False, m_bias=True, vary_baryons=False, IA_marg=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,photoz=False, m_bias=False, vary_baryons=True, IA_marg=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(desi=False,shear=True,red=False,blue=True,ok=True,w=True,photoz=False, m_bias=False, vary_baryons=False, IA_marg=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
dict_test_wok = []

pars=[com.ParamRun(parname) for parname in parlist]

for i in tqdm_notebook(range(len(parlist))):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()

    dict_test_wok.append(pars[i].get_params())
# Out:
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueFalseFalseFalseTrueFalse1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 15 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueFalseFalseTrueTrueFalse1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 33 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueTrueFalseFalseTrueFalse1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 24 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * 9 multiplicative bias parameters
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueFalseTrueFalseTrueFalse1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 17 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
# Adding prior on photo-z bias
# Adding prior on photo-z bias
# Adding prior on photo-z bias
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_fidFalseTrueFalseTrueTrueTrueFalseFalseFalseTrueTrue1.0
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 3 (3) bins used (read) for CMB primary
#   - 1 (1) bins used (read) for CMB lensing
#   - 22 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 19 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.782
#     * abias_LSST_gold_sh_node2 : 1.919
#     * abias_LSST_gold_sh_node3 : 5.755
#     * abias_LSST_gold_sh_node4 : 17.002
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 5.9366E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.7082E+01(m) +- 1.3295E+00(f)
#  - och2 = 1.1970E-01 +- 4.2835E-04(m) +- 3.3814E-05(f)
#  - hh = 6.9000E-01 +- 9.7455E-03(m) +- 1.5935E-04(f)
#  - obh2 = 2.2220E-02 +- 3.0198E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.9488E-03(m) +- 4.0239E-04(f)
#  - A_s = 2.1955E+00 +- 2.3722E-02(m) +- 1.0132E-03(f)
#  - lmcb = 1.4080E+01 +- 3.9321E-02(m) +- 1.1292E-02(f)
#  - etab = 5.0000E-01 +- 1.9998E-02(m) +- 5.4281E-03(f)
#  - ok = 0.0000E+00 +- 4.8754E-04(m) +- 3.6902E-05(f)
#  - wa = 0.0000E+00 +- 2.2968E-01(m) +- 1.8073E-03(f)
#  - w0 = -1.0000E+00 +- 8.7987E-02(m) +- 4.9891E-04(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.8553E-01(m) +- 1.1559E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.9191E-01(m) +- 1.4047E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.5870E-01(m) +- 2.8693E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.2118E+00(m) +- 1.0511E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.1274E-02(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.0962E-02(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 1.2607E-02(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 1.5592E-02(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 2.5534E-02(m) +- 8.5495E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2939E-03(m) +- 1.1827E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2305E-03(m) +- 7.2381E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8
f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 7.0979E-03(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 6.8079E-03(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 6.9598E-03(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 8.7703E-03(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 1.3544E-02(m) +- 8.5495E-03(f)
# Fisher forecast :
#  - tau = 6.0000E-02 +- 5.8321E-03(m) +- 2.7718E-04(f)
#  - mnu = 6.0000E+01 +- 2.6015E+01(m) +- 1.3295E+00(f)
#  - och2 = 1.1970E-01 +- 4.0600E-04(m) +- 3.3814E-05(f)
#  - hh = 6.9000E-01 +- 3.7367E-03(m) +- 1.5935E-04(f)
#  - obh2 = 2.2220E-02 +- 2.9445E-05(m) +- 1.2092E-05(f)
#  - ns = 9.6550E-01 +- 1.8790E-03(m) +- 4.0239E-04(f)
#  - A_s = 2.1955E+00 +- 2.3175E-02(m) +- 1.0132E-03(f)
#  - ok = 0.0000E+00 +- 4.7937E-04(m) +- 3.6902E-05(f)
#  - wa = 0.0000E+00 +- 1.2104E-01(m) +- 1.8073E-03(f)
#  - w0 = -1.0000E+00 +- 3.9831E-02(m) +- 4.9891E-04(f)
#  - abias_LSST_gold_sh_node1 = 7.8227E-01 +- 1.3490E-01(m) +- 1.1559E-01(f)
#  - abias_LSST_gold_sh_node2 = 1.9187E+00 +- 1.6802E-01(m) +- 1.4047E-01(f)
#  - abias_LSST_gold_sh_node3 = 5.7547E+00 +- 3.3834E-01(m) +- 2.8693E-01(f)
#  - abias_LSST_gold_sh_node4 = 1.7002E+01 +- 1.1624E+00(m) +- 1.0511E+00(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 7.1305E-03(m) +- 4.2309E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 6.6140E-03(m) +- 3.4053E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 6.9622E-03(m) +- 3.7305E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 8.7827E-03(m) +- 4.1811E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 1.3507E-02(m) +- 8.5495E-03(f)

# %%
# Simple data to display in various forms
mnu_fid =  [60 for i in range(len(dict_test_wok))]
w0_fid =  [-1 for i in range(len(dict_test_wok))]
wa_fid =  [0 for i in range(len(dict_test_wok))]
ok_fid =  [0 for i in range(len(dict_test_wok))]


x = range(len(dict_test_wok))

mnu_sys = [dict_test_wok[i]['mnu'] for i in range(len(dict_test_wok))]
w0_sys = [dict_test_wok[i]['w0'] for i in range(len(dict_test_wok))]
wa_sys = [dict_test_wok[i]['wa'] for i in range(len(dict_test_wok))]
ok_sys = [dict_test_wok[i]['ok'] for i in range(len(dict_test_wok))]




# Three subplots sharing both x/y axes
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False,figsize=(7,10))
ax1.errorbar(x, mnu_fid, yerr=mnu_sys, fmt='o', capsize=10)
ax1.set_ylim(60-40,60+40)
# ax1.set_title('Systematics')
ax1.set_ylabel("$\Sigma m_\\nu$ [meV]")
ax1.axhline(60, color='cornflowerblue', lw=0.2, ls='--')
ax1.axhline(mnu_fid[0]+mnu_sys[0], color='grey', lw=0.5, ls='dotted')
ax1.axhline(mnu_fid[0]-mnu_sys[0], color='grey', lw=0.5, ls='dotted')




ax2.errorbar(x, w0_fid, yerr=w0_sys, fmt='o', color='firebrick', capsize=10)
ax2.set_ylim(-1-0.2,-1+0.2)
ax2.set_ylabel("$w_0$")
ax2.axhline(-1, color='firebrick', lw=0.2, ls='--')
ax2.axhline(w0_fid[0]+w0_sys[0], color='grey', lw=0.5, ls='dotted')
ax2.axhline(w0_fid[0]-w0_sys[0], color='grey', lw=0.5, ls='dotted')


ax3.errorbar(x, wa_fid, yerr=wa_sys, fmt='o', color='forestgreen', capsize=10)
ax3.set_ylim(0-0.4,0+0.4)
ax3.set_ylabel("$w_a$")
ax3.axhline(0, color='forestgreen', lw=0.2, ls='--')
ax3.axhline(wa_fid[0]+wa_sys[0], color='grey', lw=0.5, ls='dotted')
ax3.axhline(wa_fid[0]-wa_sys[0], color='grey', lw=0.5, ls='dotted')




ax4.errorbar(x, ok_fid, yerr=ok_sys, fmt='o', color='darkorange', capsize=10)
ax4.set_ylim(0-0.001,0+0.001)
ax4.set_ylabel("$\Omega_k$")
ax4.axhline(0, color='darkorange', lw=0.2, ls='--')
ax4.axhline(ok_fid[0]+ok_sys[0], color='grey', lw=0.5, ls='dotted')
ax4.axhline(ok_fid[0]-ok_sys[0], color='grey', lw=0.5, ls='dotted')




ax4.set_xticks(x)
ax4.set_xticklabels(yticks, rotation=45)

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=.2)
# plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

plt.tight_layout()
plt.savefig(plots_dir + "systematics_indiv.pdf")

# %%
w0_sys
# Out:
# [0.087986845598102673,
#  0.038222847096521538,
#  0.048956517853688382,
#  0.040644798025363693,
#  0.04247335030368974,
#  0.039831383111886151]

# %% [markdown]
# ## No CMB

# %%
parlist = []
parnames = []

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True, shear_lmax5000=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=True,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True, photoz=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=False, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=True,ok=True,w=True,m_bias=True, vary_baryons=True, IA_marg=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
dict_test_wok = []

pars=[com.ParamRun(parname) for parname in parlist]

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()

    dict_test_wok.append(pars[i].get_params())
# Out:
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000
#   - Output spectra : ../outputs_LSST_DESI_lmax5000/run
#   - Output Fisher : FisherDellanocmbFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueTrue
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 18 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000
#   - Output spectra : ../outputs_LSST_DESI_lmax5000/run
#   - Output Fisher : FisherDellanocmbFalseTrueFalseTrueTrueTrueTrueTrueTrueFalseTrue
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 18 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 48 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000
#   - Output spectra : ../outputs_LSST_DESI_lmax5000/run
#   - Output Fisher : FisherDellanocmbFalseTrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
#   - 24 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 33 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 82 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * bias_LSST_red_cl_node1 : 1.177
#     * bias_LSST_red_cl_node2 : 1.526
#     * bias_LSST_red_cl_node3 : 1.875
#     * bias_LSST_red_cl_node4 : 2.224
#     * sphz_LSST_red_cl_node0 : 0.021
#     * sphz_LSST_red_cl_node1 : 0.022
#     * sphz_LSST_red_cl_node2 : 0.023
#     * sphz_LSST_red_cl_node3 : 0.025
#     * sphz_LSST_red_cl_node4 : 0.026
#     * sphz_LSST_red_cl_node5 : 0.028
#     * sphz_LSST_red_cl_node6 : 0.030
#     * sphz_LSST_red_cl_node7 : 0.031
#     * sphz_LSST_red_cl_node8 : 0.033
#     * sphz_LSST_red_cl_node9 : 0.035
#     * sphz_LSST_red_cl_node10 : 0.038
#     * sphz_LSST_red_cl_node11 : 0.040
#     * sphz_LSST_red_cl_node12 : 0.042
#     * sphz_LSST_red_cl_node13 : 0.045
#     * sphz_LSST_red_cl_node14 : 0.048
#     * bphz_LSST_red_cl_node0 : 0.000
#     * bphz_LSST_red_cl_node1 : 0.000
#     * bphz_LSST_red_cl_node2 : 0.000
#     * bphz_LSST_red_cl_node3 : 0.000
#     * bphz_LSST_red_cl_node4 : 0.000
#     * bphz_LSST_red_cl_node5 : 0.000
#     * bphz_LSST_red_cl_node6 : 0.000
#     * bphz_LSST_red_cl_node7 : 0.000
#     * bphz_LSST_red_cl_node8 : 0.000
#     * bphz_LSST_red_cl_node9 : 0.000
#     * bphz_LSST_red_cl_node10 : 0.000
#     * bphz_LSST_red_cl_node11 : 0.000
#     * bphz_LSST_red_cl_node12 : 0.000
#     * bphz_LSST_red_cl_node13 : 0.000
#     * bphz_LSST_red_cl_node14 : 0.000
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000
#   - Output spectra : ../outputs_LSST_DESI_lmax5000/run
#   - Output Fisher : FisherDellanocmbFalseTrueFalseTrueTrueTrueTrueTrueFalseTrueTrue
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 18 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 30 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000
#   - Output spectra : ../outputs_LSST_DESI_lmax5000/run
#   - Output Fisher : FisherDellanocmbFalseTrueFalseTrueTrueTrueTrueFalseTrueTrueTrue
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 18 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 46 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000
#   - Output spectra : ../outputs_LSST_DESI_lmax5000/run
#   - Output Fisher : FisherDellanocmbFalseTrueFalseTrueTrueTrueFalseTrueTrueTrueTrue
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 18 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 39 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000
#   - Output spectra : ../outputs_LSST_DESI_lmax5000/run
#   - Output Fisher : FisherDellanocmbFalseTrueFalseTrueTrueTrueTrueTrueTrueTrueFalse
#   - 9 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 18 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 44 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * bias_LSST_blue_cl_node1 : 1.212
#     * bias_LSST_blue_cl_node2 : 1.619
#     * bias_LSST_blue_cl_node3 : 2.047
#     * bias_LSST_blue_cl_node4 : 2.557
#     * bias_LSST_blue_cl_node5 : 3.188
#     * sphz_LSST_blue_cl_node0 : 0.054
#     * sphz_LSST_blue_cl_node1 : 0.063
#     * sphz_LSST_blue_cl_node2 : 0.073
#     * sphz_LSST_blue_cl_node3 : 0.085
#     * sphz_LSST_blue_cl_node4 : 0.099
#     * sphz_LSST_blue_cl_node5 : 0.115
#     * sphz_LSST_blue_cl_node6 : 0.133
#     * sphz_LSST_blue_cl_node7 : 0.155
#     * sphz_LSST_blue_cl_node8 : 0.180
#     * bphz_LSST_blue_cl_node0 : 0.000
#     * bphz_LSST_blue_cl_node1 : 0.000
#     * bphz_LSST_blue_cl_node2 : 0.000
#     * bphz_LSST_blue_cl_node3 : 0.000
#     * bphz_LSST_blue_cl_node4 : 0.000
#     * bphz_LSST_blue_cl_node5 : 0.000
#     * bphz_LSST_blue_cl_node6 : 0.000
#     * bphz_LSST_blue_cl_node7 : 0.000
#     * bphz_LSST_blue_cl_node8 : 0.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
# /group/hepheno/heptools/anaconda3/envs/venv_py27/lib/python2.7/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# /group/hepheno/heptools/anaconda3/envs/venv_py27/lib/python2.7/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   warnings.warn(msg, IntegrationWarning)
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 5
#  - ns = 9.6550E-01 +- 2.4832E-02(m) +- 1.1214E-03(f)
#  - A_s = 2.1955E+00 +- 2.0725E-01(m) +- 2.3751E-03(f)
#  - lmcb = 1.4080E+01 +- 1.4104E-01(m) +- 1.6875E-02(f)
#  - etab = 5.0000E-01 +- 4.2355E-02(m) +- 6.4740E-03(f)
#  - ok = 0.0000E+00 +- 1.1756E-02(m) +- 5.8031E-04(f)
#  - wa = 0.0000E+00 +- 4.5940E-01(m) +- 6.5154E-03(f)
#  - w0 = -1.0000E+00 +- 1.3203E-01(m) +- 1.8270E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 3.9530E-01(m) +- 2.4726E-01(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 4.0715E-01(m) +- 2.8884E-01(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 2.8828E+00(m) +- 2.4710E+00(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 3.0102E+03(m) +- 2.8812E+03(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 2.3139E-02(m) +- 4.2470E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 3.4709E-02(m) +- 3.4464E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 4.5957E-02(m) +- 3.8144E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 6.9867E-02(m) +- 4.2858E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 9.3652E-02(m) +- 8.6704E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.3468E-03(m) +- 1.1844E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.3593E-03(m) +- 7.2539E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 1.0228E-03(m) +- 6.1248E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.2613E-03(m) +- 5.5967E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 1.0263E-03(m) +- 5.3645E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.8378E-03(m) +- 5.5079E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.5459E-03(m) +- 5.3273E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 2.2930E-03(m) +- 5.0327E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 3.0080E-03(m) +- 5.2581E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.4057E-03(m) +- 1.6641E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 2.2565E-03(m) +- 8.4725E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.9850E-03(m) +- 7.8328E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.8057E-03(m) +- 7.5813E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 2.0057E-03(m) +- 7.5893E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 2.3955E-03(m) +- 7.8492E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.8865E-03(m) +- 7.9160E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 4.3089E-03(m) +- 8.7436E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.9584E-03(m) +- 1.2685E-03(f)
#  - m0 = 0.0+- 8.1469E-02(m) +- 7.8885E-02(f)
#  - m1 = 0.0+- 1.6433E-02(m) +- 1.3277E-02(f)
#  - m2 = 0.0+- 5.8226E-03(m) +- 4.5187E-03(f)
#  - m3 = 0.0+- 2.5733E-03(m) +- 2.2600E-03(f)
#  - m4 = 0.0+- 1.6025E-03(m) +- 1.4526E-03(f)
#  - m5 = 0.0+- 1.2143E-03(m) +- 1.1365E-03(f)
#  - m6 = 0.0+- 1.1153E-03(m) +- 1.0528E-03(f)
#  - m7 = 0.0+- 1.2194E-03(m) +- 1.1370E-03(f)
#  - m8 = 0.0+- 1.5609E-03(m) +- 1.4183E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for bias_LSST_red_cl_node1
# Deriv for bias_LSST_red_cl_node2
# Deriv for bias_LSST_red_cl_node3
# Deriv for bias_LSST_red_cl_node4
# Deriv for sphz_LSST_red_cl_node0
# Deriv for sphz_LSST_red_cl_node1
# Deriv for sphz_LSST_red_cl_node2
# Deriv for sphz_LSST_red_cl_node3
# Deriv for sphz_LSST_red_cl_node4
# Deriv for sphz_LSST_red_cl_node5
# Deriv for sphz_LSST_red_cl_node6
# Deriv for sphz_LSST_red_cl_node7
# Deriv for sphz_LSST_red_cl_node8
# Deriv for sphz_LSST_red_cl_node9
# Deriv for sphz_LSST_red_cl_node10
# Deriv for sphz_LSST_red_cl_node11
# Deriv for sphz_LSST_red_cl_node12
# Deriv for sphz_LSST_red_cl_node13
# Deriv for sphz_LSST_red_cl_node14
# Deriv for bphz_LSST_red_cl_node0
# Deriv for bphz_LSST_red_cl_node1
# Deriv for bphz_LSST_red_cl_node2
# Deriv for bphz_LSST_red_cl_node3
# Deriv for bphz_LSST_red_cl_node4
# Deriv for bphz_LSST_red_cl_node5
# Deriv for bphz_LSST_red_cl_node6
# Deriv for bphz_LSST_red_cl_node7
# Deriv for bphz_LSST_red_cl_node8
# Deriv for bphz_LSST_red_cl_node9
# Deriv for bphz_LSST_red_cl_node10
# Deriv for bphz_LSST_red_cl_node11
# Deriv for bphz_LSST_red_cl_node12
# Deriv for bphz_LSST_red_cl_node13
# Deriv for bphz_LSST_red_cl_node14
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#    LSST_red_cl
# 0 24889.9795124 0.0 0.061856 0.020619
# 1 147321.217934 0.061856 0.127537 0.021894
# 2 406015.293655 0.127537 0.197282 0.023248
# 3 812715.239133 0.197282 0.271341 0.024686
# 4 1369550.89021 0.271341 0.34998 0.026213
# 5 2064841.3261 0.34998 0.433484 0.027835
# 6 2865354.93141 0.433484 0.522153 0.029556
# 7 3704790.65112 0.522153 0.616307 0.031385
# 8 4467181.19403 0.616307 0.716285 0.033326
# 9 4969107.43958 0.716285 0.822447 0.035387
# 10 4959260.90731 0.822447 0.935176 0.037576
# 11 4198144.10961 0.935176 1.054877 0.039901
# 12 2726849.90098 1.054877 1.181983 0.042369
# 13 1168583.06499 1.181983 1.316951 0.044989
# 14 274968.734453 1.316951 1.460268 0.047772
#
#
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Adding a prior of 0.005 for bphz_LSST_red_cl_node0
# Adding a prior of 0.005 for bphz_LSST_red_cl_node1
# Adding a prior of 0.005 for bphz_LSST_red_cl_node2
# Adding a prior of 0.005 for bphz_LSST_red_cl_node3
# Adding a prior of 0.005 for bphz_LSST_red_cl_node4
# Adding a prior of 0.005 for bphz_LSST_red_cl_node5
# Adding a prior of 0.005 for bphz_LSST_red_cl_node6
# Adding a prior of 0.005 for bphz_LSST_red_cl_node7
# Adding a prior of 0.005 for bphz_LSST_red_cl_node8
# Adding a prior of 0.005 for bphz_LSST_red_cl_node9
# Adding a prior of 0.005 for bphz_LSST_red_cl_node10
# Adding a prior of 0.005 for bphz_LSST_red_cl_node11
# Adding a prior of 0.005 for bphz_LSST_red_cl_node12
# Adding a prior of 0.005 for bphz_LSST_red_cl_node13
# Adding a prior of 0.005 for bphz_LSST_red_cl_node14
# Fisher forecast :
#  - tau = 6.0000E-02 +- 2.8552E-01(m) +- 1.4045E-01(f)
#  - mnu = 6.0000E+01 +- 6.4322E+01(m) +- 1.9331E+00(f)
#  - och2 = 1.1970E-01 +- 2.7182E-03(m) +- 5.3463E-05(f)
#  - hh = 6.9000E-01 +- 8.5076E-03(m) +- 4.6927E-04(f)
#  - obh2 = 2.2220E-02 +- 1.0098E-03(m) +- 6.0764E-05(f)
#  - ns = 9.6550E-01 +- 8.1859E-03(m) +- 7.2412E-04(f)
#  - A_s = 2.1955E+00 +- 6.6484E-02(m) +- 1.8511E-03(f)
#  - lmcb = 1.4080E+01 +- 8.1364E-02(m) +- 1.1456E-02(f)
#  - etab = 5.0000E-01 +- 1.9454E-02(m) +- 5.7326E-03(f)
#  - ok = 0.0000E+00 +- 1.3333E-03(m) +- 4.1307E-04(f)
#  - wa = 0.0000E+00 +- 1.4065E-01(m) +- 5.0171E-03(f)
#  - w0 = -1.0000E+00 +- 4.7795E-02(m) +- 1.4463E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 3.1848E-01(m) +- 2.1605E-01(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 3.3795E-01(m) +- 2.6202E-01(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 2.4538E+00(m) +- 2.1973E+00(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 2.8839E+03(m) +- 2.8214E+03(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.2205E-02(m) +- 1.8289E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 1.6846E-02(m) +- 1.4594E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 2.2643E-02(m) +- 2.3793E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 3.2667E-02(m) +- 4.2197E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 4.6661E-02(m) +- 8.6655E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 1.3939E-03(m) +- 4.9748E-04(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 6.5420E-04(m) +- 2.7201E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 4.8273E-04(m) +- 2.2458E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 5.8389E-04(m) +- 2.0917E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 5.8137E-04(m) +- 1.9653E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.0057E-03(m) +- 3.5731E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.3705E-03(m) +- 4.9107E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 1.8648E-03(m) +- 4.9555E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 2.9068E-03(m) +- 5.2465E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 2.0849E-03(m) +- 5.5444E-04(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.1495E-03(m) +- 2.2593E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.1894E-03(m) +- 1.8789E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.1466E-03(m) +- 1.7849E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.1843E-03(m) +- 1.7329E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 1.5730E-03(m) +- 3.5151E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.2697E-03(m) +- 6.9983E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 3.9904E-03(m) +- 8.5963E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.9509E-03(m) +- 1.2646E-03(f)
#  - bias_LSST_red_cl_node1 = 1.1771E+00 +- 1.1475E-02(m) +- 2.8988E-03(f)
#  - bias_LSST_red_cl_node2 = 1.5260E+00 +- 1.5455E-02(m) +- 1.8177E-03(f)
#  - bias_LSST_red_cl_node3 = 1.8750E+00 +- 1.8871E-02(m) +- 1.8581E-03(f)
#  - bias_LSST_red_cl_node4 = 2.2240E+00 +- 2.7242E-02(m) +- 3.1668E-03(f)
#  - sphz_LSST_red_cl_node0 = 2.0619E-02 +- 1.8740E-03(m) +- 8.2787E-04(f)
#  - sphz_LSST_red_cl_node1 = 2.1894E-02 +- 6.2168E-04(m) +- 3.9649E-04(f)
#  - sphz_LSST_red_cl_node2 = 2.3248E-02 +- 5.7977E-04(m) +- 3.4404E-04(f)
#  - sphz_LSST_red_cl_node3 = 2.4686E-02 +- 3.3883E-04(m) +- 1.9299E-04(f)
#  - sphz_LSST_red_cl_node4 = 2.6213E-02 +- 3.4977E-04(m) +- 2.0096E-04(f)
#  - sphz_LSST_red_cl_node5 = 2.7835E-02 +- 2.8955E-04(m) +- 1.7521E-04(f)
#  - sphz_LSST_red_cl_node6 = 2.9556E-02 +- 2.4899E-04(m) +- 1.4531E-04(f)
#  - sphz_LSST_red_cl_node7 = 3.1385E-02 +- 2.9450E-04(m) +- 1.7878E-04(f)
#  - sphz_LSST_red_cl_node8 = 3.3326E-02 +- 2.4403E-04(m) +- 1.3625E-04(f)
#  - sphz_LSST_red_cl_node9 = 3.5387E-02 +- 2.8706E-04(m) +- 1.5946E-04(f)
#  - sphz_LSST_red_cl_node10 = 3.7576E-02 +- 3.1936E-04(m) +- 1.5130E-04(f)
#  - sphz_LSST_red_cl_node11 = 3.9901E-02 +- 2.7218E-04(m) +- 1.4085E-04(f)
#  - sphz_LSST_red_cl_node12 = 4.2369E-02 +- 3.6587E-04(m) +- 1.9252E-04(f)
#  - sphz_LSST_red_cl_node13 = 4.4989E-02 +- 4.3308E-04(m) +- 2.0997E-04(f)
#  - sphz_LSST_red_cl_node14 = 4.7772E-02 +- 7.1931E-04(m) +- 2.8134E-04(f)
#  - bphz_LSST_red_cl_node0 = 0.0000E+00 +- 3.5349E-03(m) +- 1.5972E-03(f)
#  - bphz_LSST_red_cl_node1 = 0.0000E+00 +- 1.3270E-03(m) +- 5.5343E-04(f)
#  - bphz_LSST_red_cl_node2 = 0.0000E+00 +- 1.1373E-03(m) +- 4.4477E-04(f)
#  - bphz_LSST_red_cl_node3 = 0.0000E+00 +- 1.0352E-03(m) +- 2.4197E-04(f)
#  - bphz_LSST_red_cl_node4 = 0.0000E+00 +- 1.0934E-03(m) +- 2.4614E-04(f)
#  - bphz_LSST_red_cl_node5 = 0.0000E+00 +- 1.1038E-03(m) +- 2.1748E-04(f)
#  - bphz_LSST_red_cl_node6 = 0.0000E+00 +- 1.0904E-03(m) +- 1.7718E-04(f)
#  - bphz_LSST_red_cl_node7 = 0.0000E+00 +- 1.1639E-03(m) +- 2.1960E-04(f)
#  - bphz_LSST_red_cl_node8 = 0.0000E+00 +- 1.0920E-03(m) +- 1.6703E-04(f)
#  - bphz_LSST_red_cl_node9 = 0.0000E+00 +- 1.1443E-03(m) +- 1.9314E-04(f)
#  - bphz_LSST_red_cl_node10 = 0.0000E+00 +- 1.1532E-03(m) +- 1.8373E-04(f)
#  - bphz_LSST_red_cl_node11 = 0.0000E+00 +- 1.1981E-03(m) +- 1.6690E-04(f)
#  - bphz_LSST_red_cl_node12 = 0.0000E+00 +- 1.3788E-03(m) +- 2.5048E-04(f)
#  - bphz_LSST_red_cl_node13 = 0.0000E+00 +- 1.5318E-03(m) +- 3.1281E-04(f)
#  - bphz_LSST_red_cl_node14 = 0.0000E+00 +- 2.1526E-03(m) +- 5.4059E-04(f)
#  - m0 = 0.0+- 7.4630E-02(m) +- 7.4060E-02(f)
#  - m1 = 0.0+- 1.3768E-02(m) +- 1.2565E-02(f)
#  - m2 = 0.0+- 5.1215E-03(m) +- 4.1952E-03(f)
#  - m3 = 0.0+- 2.3575E-03(m) +- 2.0773E-03(f)
#  - m4 = 0.0+- 1.4896E-03(m) +- 1.3382E-03(f)
#  - m5 = 0.0+- 1.1409E-03(m) +- 1.0535E-03(f)
#  - m6 = 0.0+- 1.0570E-03(m) +- 9.8095E-04(f)
#  - m7 = 0.0+- 1.1554E-03(m) +- 1.0620E-03(f)
#  - m8 = 0.0+- 1.4543E-03(m) +- 1.3214E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886239.79106 2.327621 2.867235 0.17987
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 4.4757E-01(m) +- 1.7731E-01(f)
#  - mnu = 6.0000E+01 +- 8.1025E+01(m) +- 2.1189E+00(f)
#  - och2 = 1.1970E-01 +- 7.3046E-03(m) +- 5.5463E-05(f)
#  - hh = 6.9000E-01 +- 2.3325E-02(m) +- 4.8432E-04(f)
#  - obh2 = 2.2220E-02 +- 2.3336E-03(m) +- 6.9103E-05(f)
#  - ns = 9.6550E-01 +- 1.6097E-02(m) +- 7.6298E-04(f)
#  - A_s = 2.1955E+00 +- 1.3530E-01(m) +- 2.0042E-03(f)
#  - lmcb = 1.4080E+01 +- 1.1266E-01(m) +- 1.1616E-02(f)
#  - etab = 5.0000E-01 +- 2.2536E-02(m) +- 5.7415E-03(f)
#  - ok = 0.0000E+00 +- 1.1179E-02(m) +- 4.5634E-04(f)
#  - wa = 0.0000E+00 +- 2.1611E-01(m) +- 5.0949E-03(f)
#  - w0 = -1.0000E+00 +- 6.0100E-02(m) +- 1.4608E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 3.1748E-01(m) +- 2.2163E-01(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 3.6906E-01(m) +- 2.7358E-01(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 2.7509E+00(m) +- 2.4217E+00(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 2.8907E+03(m) +- 2.8714E+03(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.4394E-02(m) +- 4.2470E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 2.3636E-02(m) +- 3.4464E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 3.1742E-02(m) +- 3.8144E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 4.3431E-02(m) +- 4.2858E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 5.7798E-02(m) +- 8.6704E-03(f)
#  - m0 = 0.0+- 7.8202E-02(m) +- 7.7924E-02(f)
#  - m1 = 0.0+- 1.3817E-02(m) +- 1.2819E-02(f)
#  - m2 = 0.0+- 5.1853E-03(m) +- 4.2647E-03(f)
#  - m3 = 0.0+- 2.3912E-03(m) +- 2.1137E-03(f)
#  - m4 = 0.0+- 1.5250E-03(m) +- 1.3614E-03(f)
#  - m5 = 0.0+- 1.1650E-03(m) +- 1.0704E-03(f)
#  - m6 = 0.0+- 1.0692E-03(m) +- 9.9428E-04(f)
#  - m7 = 0.0+- 1.1659E-03(m) +- 1.0722E-03(f)
#  - m8 = 0.0+- 1.4757E-03(m) +- 1.3290E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +-
#  - lmcb = 1.4080E+01 +- 1.2183E-01(m) +- 1.1616E-02(f)
#  - etab = 5.0000E-01 +- 2.6039E-02(m) +- 5.7415E-03(f)
#  - ok = 0.0000E+00 +- 1.1476E-02(m) +- 4.5634E-04(f)
#  - wa = 0.0000E+00 +- 3.0591E-01(m) +- 5.0949E-03(f)
#  - w0 = -1.0000E+00 +- 9.5793E-02(m) +- 1.4608E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 3.6840E-01(m) +- 2.2163E-01(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 3.9036E-01(m) +- 2.7358E-01(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 2.8101E+00(m) +- 2.4217E+00(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 2.9998E+03(m) +- 2.8714E+03(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.9551E-02(m) +- 4.2470E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 2.6935E-02(m) +- 3.4464E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 3.5339E-02(m) +- 3.8144E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 5.3960E-02(m) +- 4.2858E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 7.1132E-02(m) +- 8.6704E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2979E-03(m) +- 1.1844E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2872E-03(m) +- 7.2539E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 8.8921E-04(m) +- 6.1248E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.2022E-03(m) +- 5.5967E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 1.0023E-03(m) +- 5.3645E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.8005E-03(m) +- 5.5079E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.5306E-03(m) +- 5.3273E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 2.2860E-03(m) +- 5.0327E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 3.0074E-03(m) +- 5.2581E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.1934E-03(m) +- 1.6641E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.7778E-03(m) +- 8.4725E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.7716E-03(m) +- 7.8328E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.6432E-03(m) +- 7.5813E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.8602E-03(m) +- 7.5893E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 2.3314E-03(m) +- 7.8492E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.8619E-03(m) +- 7.9160E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 4.3026E-03(m) +- 8.7436E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.9582E-03(m) +- 1.2685E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for bias_LSST_blue_cl_node1
# Deriv for bias_LSST_blue_cl_node2
# Deriv for bias_LSST_blue_cl_node3
# Deriv for bias_LSST_blue_cl_node4
# Deriv for bias_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node0
# Deriv for sphz_LSST_blue_cl_node1
# Deriv for sphz_LSST_blue_cl_node2
# Deriv for sphz_LSST_blue_cl_node3
# Deriv for sphz_LSST_blue_cl_node4
# Deriv for sphz_LSST_blue_cl_node5
# Deriv for sphz_LSST_blue_cl_node6
# Deriv for sphz_LSST_blue_cl_node7
# Deriv for sphz_LSST_blue_cl_node8
# Deriv for bphz_LSST_blue_cl_node0
# Deriv for bphz_LSST_blue_cl_node1
# Deriv for bphz_LSST_blue_cl_node2
# Deriv for bphz_LSST_blue_cl_node3
# Deriv for bphz_LSST_blue_cl_node4
# Deriv for bphz_LSST_blue_cl_node5
# Deriv for bphz_LSST_blue_cl_node6
# Deriv for bphz_LSST_blue_cl_node7
# Deriv for bphz_LSST_blue_cl_node8
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#    LSST_blue_cl
# 0 14931216.1922 -0.0 0.162162 0.054054
# 1 49109007.0275 0.162162 0.350621 0.06282
# 2 79018539.4946 0.350621 0.56964 0.073007
# 3 92296654.9546 0.56964 0.824177 0.084845
# 4 89279140.6194 0.824177 1.119989 0.098604
# 5 75327183.8974 1.119989 1.463771 0.114594
# 6 47554508.2141 1.463771 1.863302 0.133177
# 7 19267797.5052 1.863302 2.327621 0.154773
# 8 3886250.59716 2.327621 2.867235 0.179871
#
#
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node0
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node1
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node2
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node3
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node4
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node5
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node6
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node7
# Adding a prior of 0.005 for bphz_LSST_blue_cl_node8
# Fisher forecast :
#  - tau = 6.0000E-02 +- 4.8351E-01(m) +- 1.7731E-01(f)
#  - mnu = 6.0000E+01 +- 8.4933E+01(m) +- 2.1189E+00(f)
#  - och2 = 1.1970E-01 +- 7.7662E-03(m) +- 5.5463E-05(f)
#  - hh = 6.9000E-01 +- 2.5971E-02(m) +- 4.8432E-04(f)
#  - obh2 = 2.2220E-02 +- 2.4462E-03(m) +- 6.9103E-05(f)
#  - ns = 9.6550E-01 +- 1.7423E-02(m) +- 7.6298E-04(f)
#  - A_s = 2.1955E+00 +- 1.4781E-01(m) +- 2.0042E-03(f)
#  - lmcb = 1.4080E+01 +- 1.2273E-01(m) +- 1.1616E-02(f)
#  - etab = 5.0000E-01 +- 2.6025E-02(m) +- 5.7415E-03(f)
#  - ok = 0.0000E+00 +- 1.1499E-02(m) +- 4.5634E-04(f)
#  - wa = 0.0000E+00 +- 3.0938E-01(m) +- 5.0949E-03(f)
#  - w0 = -1.0000E+00 +- 9.6830E-02(m) +- 1.4608E-03(f)
#  - bias_LSST_blue_cl_node1 = 1.2119E+00 +- 1.9876E-02(m) +- 4.2470E-03(f)
#  - bias_LSST_blue_cl_node2 = 1.6192E+00 +- 2.6808E-02(m) +- 3.4464E-03(f)
#  - bias_LSST_blue_cl_node3 = 2.0465E+00 +- 3.6060E-02(m) +- 3.8144E-03(f)
#  - bias_LSST_blue_cl_node4 = 2.5575E+00 +- 5.3471E-02(m) +- 4.2858E-03(f)
#  - bias_LSST_blue_cl_node5 = 3.1875E+00 +- 7.1196E-02(m) +- 8.6704E-03(f)
#  - sphz_LSST_blue_cl_node0 = 5.4054E-02 +- 2.2831E-03(m) +- 1.1844E-03(f)
#  - sphz_LSST_blue_cl_node1 = 6.2820E-02 +- 1.2991E-03(m) +- 7.2539E-04(f)
#  - sphz_LSST_blue_cl_node2 = 7.3007E-02 +- 9.0877E-04(m) +- 6.1248E-04(f)
#  - sphz_LSST_blue_cl_node3 = 8.4845E-02 +- 1.1664E-03(m) +- 5.5967E-04(f)
#  - sphz_LSST_blue_cl_node4 = 9.8604E-02 +- 9.5266E-04(m) +- 5.3645E-04(f)
#  - sphz_LSST_blue_cl_node5 = 1.1459E-01 +- 1.7055E-03(m) +- 5.5079E-04(f)
#  - sphz_LSST_blue_cl_node6 = 1.3318E-01 +- 1.5115E-03(m) +- 5.3273E-04(f)
#  - sphz_LSST_blue_cl_node7 = 1.5477E-01 +- 2.2370E-03(m) +- 5.0327E-04(f)
#  - sphz_LSST_blue_cl_node8 = 1.7987E-01 +- 3.0059E-03(m) +- 5.2581E-04(f)
#  - bphz_LSST_blue_cl_node0 = 0.0000E+00 +- 3.2603E-03(m) +- 1.6641E-03(f)
#  - bphz_LSST_blue_cl_node1 = 0.0000E+00 +- 1.7981E-03(m) +- 8.4725E-04(f)
#  - bphz_LSST_blue_cl_node2 = 0.0000E+00 +- 1.6817E-03(m) +- 7.8328E-04(f)
#  - bphz_LSST_blue_cl_node3 = 0.0000E+00 +- 1.5017E-03(m) +- 7.5813E-04(f)
#  - bphz_LSST_blue_cl_node4 = 0.0000E+00 +- 1.7059E-03(m) +- 7.5893E-04(f)
#  - bphz_LSST_blue_cl_node5 = 0.0000E+00 +- 2.1630E-03(m) +- 7.8492E-04(f)
#  - bphz_LSST_blue_cl_node6 = 0.0000E+00 +- 2.7289E-03(m) +- 7.9160E-04(f)
#  - bphz_LSST_blue_cl_node7 = 0.0000E+00 +- 4.2996E-03(m) +- 8.7436E-04(f)
#  - bphz_LSST_blue_cl_node8 = 0.0000E+00 +- 4.9582E-03(m) +- 1.2685E-03(f)
#  - m0 = 0.0+- 7.9771E-02(m) +- 7.7924E-02(f)
#  - m1 = 0.0+- 1.5526E-02(m) +- 1.2819E-02(f)
#  - m2 = 0.0+- 5.6484E-03(m) +- 4.2647E-03(f)
#  - m3 = 0.0+- 2.4876E-03(m) +- 2.1137E-03(f)
#  - m4 = 0.0+- 1.5329E-03(m) +- 1.3614E-03(f)
#  - m5 = 0.0+- 1.1676E-03(m) +- 1.0704E-03(f)
#  - m6 = 0.0+- 1.0755E-03(m) +- 9.9428E-04(f)
#  - m7 = 0.0+- 1.1729E-03(m) +- 1.0722E-03(f)
#  - m8 = 0.0+- 1.4900E-03(m) +- 1.3290E-03(f)

# %%
yticks = ["Fiducial", "Shear $\ell_\mathrm{max}= 2000", "Red sample", "No photo-$z$ marg.", "No baryon marg.", "No $m$-bias","No IA marg."]

# %%
# Simple data to display in various forms
mnu_fid =  [60 for i in range(len(dict_test_wok))]
w0_fid =  [-1 for i in range(len(dict_test_wok))]
wa_fid =  [0 for i in range(len(dict_test_wok))]
ok_fid =  [0 for i in range(len(dict_test_wok))]


x = range(len(dict_test_wok))

mnu_sys = [dict_test_wok[i]['mnu'] for i in range(len(dict_test_wok))]
w0_sys = [dict_test_wok[i]['w0'] for i in range(len(dict_test_wok))]
wa_sys = [dict_test_wok[i]['wa'] for i in range(len(dict_test_wok))]
ok_sys = [dict_test_wok[i]['ok'] for i in range(len(dict_test_wok))]




# Three subplots sharing both x/y axes
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False,figsize=(7,10))
ax1.errorbar(x, mnu_fid, yerr=mnu_sys, fmt='o', capsize=10)
ax1.set_ylim(60-150,60+150)
# ax1.set_title('Systematics')
ax1.set_ylabel("$\Sigma m_\\nu$ [meV]")
ax1.axhline(60, color='cornflowerblue', lw=0.2, ls='--')
ax1.axhline(mnu_fid[0]+mnu_sys[0], color='grey', lw=0.5, ls='dotted')
ax1.axhline(mnu_fid[0]-mnu_sys[0], color='grey', lw=0.5, ls='dotted')

ax1.set_title("No CMB")

ax2.errorbar(x, w0_fid, yerr=w0_sys, fmt='o', color='firebrick', capsize=10)
ax2.set_ylim(-1-0.2,-1+0.2)
ax2.set_ylabel("$w_0$")
ax2.axhline(-1, color='firebrick', lw=0.2, ls='--')
ax2.axhline(w0_fid[0]+w0_sys[0], color='grey', lw=0.5, ls='dotted')
ax2.axhline(w0_fid[0]-w0_sys[0], color='grey', lw=0.5, ls='dotted')


ax3.errorbar(x, wa_fid, yerr=wa_sys, fmt='o', color='forestgreen', capsize=10)
ax3.set_ylim(0-0.4,0+0.4)
ax3.set_ylabel("$w_a$")
ax3.axhline(0, color='forestgreen', lw=0.2, ls='--')
ax3.axhline(wa_fid[0]+wa_sys[0], color='grey', lw=0.5, ls='dotted')
ax3.axhline(wa_fid[0]-wa_sys[0], color='grey', lw=0.5, ls='dotted')




ax4.errorbar(x, ok_fid, yerr=ok_sys, fmt='o', color='darkorange', capsize=10)
ax4.set_ylim(0-0.02,0+0.02)
ax4.set_ylabel("$\Omega_k$")
ax4.axhline(0, color='darkorange', lw=0.2, ls='--')
ax4.axhline(ok_fid[0]+ok_sys[0], color='grey', lw=0.5, ls='dotted')
ax4.axhline(ok_fid[0]-ok_sys[0], color='grey', lw=0.5, ls='dotted')




ax4.set_xticks(x)
ax4.set_xticklabels(yticks, rotation=45)

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=.2)
# plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

plt.tight_layout()
# plt.savefig(plots_dir + "systematics.pdf")

# %% [markdown]
# ## No CMB and clustering

# %%
parlist = []
parnames = []

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True, shear_lmax5000=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True, photoz=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=False, vary_baryons=True)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

fstr, fname = get_ini(setup="nocmb", desi=False,shear=True,red=False,blue=False,ok=True,w=True,m_bias=True, vary_baryons=True, IA_marg=False)
parlist.append(fname)
parnames.append("Marginalize over baryons")
f=open(fname, "w")
f.write(fstr)
f.close()

# %%
dict_test_wok = []

pars=[com.ParamRun(parname) for parname in parlist]

for i in range(len(parlist)):
#     pars[i] = com.ParamRun(parlist[i])
    print " "
    if (not os.path.isfile(pars[i].output_dir+"/"+pars[i].output_fisher+"/fisher_raw.npz")) :
        print "<> Computing/reading relevant signal power spectra"
        pars[i].get_cls_all()

        if pars[i].just_run_cls==False :
            print "<> Computing relevant noise power spectra"
            pars[i].get_cls_noise()
            print " "
#             pars[i].plot_cls_params()
    print " "
    pars[i].get_fisher_cls()
    pars[i].get_fisher_bao()
    pars[i].get_fisher_prior()
    pars[i].join_fishers()
    pars[i].plot_fisher()

    dict_test_wok.append(pars[i].get_params())
# Out:
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nocmbFalseTrueFalseFalseTrueTrueTrueTrueTrueTrueTrue
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 9 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 25 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nocmbFalseTrueFalseFalseTrueTrueTrueTrueTrueFalseTrue
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 9 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 25 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nocmbFalseTrueFalseFalseTrueTrueTrueTrueFalseTrueTrue
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 9 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 25 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nocmbFalseTrueFalseFalseTrueTrueTrueFalseTrueTrueTrue
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 9 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 23 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#     * 9 multiplicative bias parameters
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nocmbFalseTrueFalseFalseTrueTrueFalseTrueTrueTrueTrue
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 9 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 16 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * abias_LSST_gold_sh_node1 : 0.017
#     * abias_LSST_gold_sh_node2 : 0.043
#     * abias_LSST_gold_sh_node3 : 0.351
#     * abias_LSST_gold_sh_node4 : 0.706
#  <><> Run parameters
#   - Overall l_max = 5000
#   - LSS l_max = 5000
#   - CMB l_max = 5000
#   - Output directory : ../outputs_LSST_DESI_lmax5000_IAFix/
#   - Output spectra : ../outputs_LSST_DESI_lmax5000_IAFix//run
#   - Output Fisher : FisherDellaIAFixed_nocmbFalseTrueFalseFalseTrueTrueTrueTrueTrueTrueFalse
#   - 0 (24) bins used (read) for galaxy clustering
#   - 9 (9) bins used (read) for galaxy shear
#   - 0 (3) bins used (read) for CMB primary
#   - 0 (1) bins used (read) for CMB lensing
#   - 9 bins used in total
#   - 5 tracers read :
#      1. CMB_exp. Type: cmb_primary, 3 bins.
#      2. CMB_exp_lensing. Type: cmb_lensing, 1 bins.
#      3. LSST_gold_sh. Type: gal_shear, 9 bins.
#      4. LSST_blue_cl. Type: gal_clustering, 9 bins.
#      5. LSST_red_cl. Type: gal_clustering, 15 bins.
#   - Overlaping sky fraction : 0.400
#   - Terms included for galaxy clustering : density, rsd1
#   - Terms included for galaxy shear : lensing_shear, intrinsic_alignment
#   - 21 free parameters :
#     * tau : 0.060
#     * mnu : 60.000
#     * och2 : 0.120
#     * hh : 0.690
#     * obh2 : 0.022
#     * ns : 0.966
#     * A_s : 2.196
#     * lmcb : 14.080
#     * etab : 0.500
#     * ok : 0.000
#     * wa : 0.000
#     * w0 : -1.000
#     * 9 multiplicative bias parameters
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
# /group/hepheno/heptools/anaconda3/envs/venv_py27/lib/python2.7/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.1208E+00(m) +- 1.8199E-01(f)
#  - mnu = 6.0000E+01 +- 2.7640E+02(m) +- 2.6286E+00(f)
#  - och2 = 1.1970E-01 +- 3.6700E-02(m) +- 6.0082E-05(f)
#  - hh = 6.9000E-01 +- 1.2355E-01(m) +- 5.5371E-04(f)
#  - obh2 = 2.2220E-02 +- 1.1211E-02(m) +- 9.3566E-05(f)
#  - ns = 9.6550E-01 +- 7.0023E-02(m) +- 7.9607E-04(f)
#  - A_s = 2.1955E+00 +- 6.5252E-01(m) +- 2.4278E-03(f)
#  - lmcb = 1.4080E+01 +- 3.4804E-01(m) +- 1.1674E-02(f)
#  - etab = 5.0000E-01 +- 7.7388E-02(m) +- 5.7857E-03(f)
#  - ok = 0.0000E+00 +- 8.0020E-02(m) +- 4.7527E-04(f)
#  - wa = 0.0000E+00 +- 6.0685E-01(m) +- 5.2691E-03(f)
#  - w0 = -1.0000E+00 +- 2.0189E-01(m) +- 1.5458E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 8.1836E-02(m) +- 3.5553E-02(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 4.2966E-02(m) +- 2.2286E-02(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 6.4112E-02(m) +- 3.8513E-02(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 3.2251E-01(m) +- 1.9159E-01(f)
#  - m0 = 0.0+- 1.0089E-01(m) +- 9.5898E-02(f)
#  - m1 = 0.0+- 2.1828E-02(m) +- 1.5118E-02(f)
#  - m2 = 0.0+- 9.1022E-03(m) +- 5.0766E-03(f)
#  - m3 = 0.0+- 3.5098E-03(m) +- 2.5394E-03(f)
#  - m4 = 0.0+- 2.1875E-03(m) +- 1.6304E-03(f)
#  - m5 = 0.0+- 1.5956E-03(m) +- 1.2729E-03(f)
#  - m6 = 0.0+- 1.6221E-03(m) +- 1.1825E-03(f)
#  - m7 = 0.0+- 1.6189E-03(m) +- 1.3213E-03(f)
#  - m8 = 0.0+- 2.6631E-03(m) +- 1.7084E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.4445E+00(m) +- 2.5670E-01(f)
#  - mnu = 6.0000E+01 +- 3.3777E+02(m) +- 3.4965E+00(f)
#  - och2 = 1.1970E-01 +- 5.2071E-02(m) +- 7.9758E-05(f)
#  - hh = 6.9000E-01 +- 1.7180E-01(m) +- 7.2089E-04(f)
#  - obh2 = 2.2220E-02 +- 1.6255E-02(m) +- 1.2466E-04(f)
#  - ns = 9.6550E-01 +- 9.4567E-02(m) +- 1.2208E-03(f)
#  - A_s = 2.1955E+00 +- 8.3253E-01(m) +- 3.1711E-03(f)
#  - lmcb = 1.4080E+01 +- 3.8019E-01(m) +- 1.6921E-02(f)
#  - etab = 5.0000E-01 +- 1.0961E-01(m) +- 6.5127E-03(f)
#  - ok = 0.0000E+00 +- 1.0674E-01(m) +- 6.1804E-04(f)
#  - wa = 0.0000E+00 +- 1.2155E+00(m) +- 6.8608E-03(f)
#  - w0 = -1.0000E+00 +- 2.5068E-01(m) +- 1.9925E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 8.9347E-02(m) +- 4.1976E-02(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 4.7133E-02(m) +- 2.5045E-02(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 6.9443E-02(m) +- 4.0661E-02(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 3.3362E-01(m) +- 1.9775E-01(f)
#  - m0 = 0.0+- 1.0626E-01(m) +- 9.7467E-02(f)
#  - m1 = 0.0+- 2.5124E-02(m) +- 1.5812E-02(f)
#  - m2 = 0.0+- 9.6798E-03(m) +- 5.4917E-03(f)
#  - m3 = 0.0+- 3.6637E-03(m) +- 2.7931E-03(f)
#  - m4 = 0.0+- 2.2829E-03(m) +- 1.7890E-03(f)
#  - m5 = 0.0+- 1.6765E-03(m) +- 1.3856E-03(f)
#  - m6 = 0.0+- 1.7034E-03(m) +- 1.2826E-03(f)
#  - m7 = 0.0+- 1.6739E-03(m) +- 1.4459E-03(f)
#  - m8 = 0.0+- 2.8351E-03(m) +- 1.9064E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.1208E+00(m) +- 1.8199E-01(f)
#  - mnu = 6.0000E+01 +- 2.7640E+02(m) +- 2.6286E+00(f)
#  - och2 = 1.1970E-01 +- 3.6700E-02(m) +- 6.0082E-05(f)
#  - hh = 6.9000E-01 +- 1.2355E-01(m) +- 5.5371E-04(f)
#  - obh2 = 2.2220E-02 +- 1.1211E-02(m) +- 9.3566E-05(f)
#  - ns = 9.6550E-01 +- 7.0023E-02(m) +- 7.9607E-04(f)
#  - A_s = 2.1955E+00 +- 6.5252E-01(m) +- 2.4278E-03(f)
#  - lmcb = 1.4080E+01 +- 3.4804E-01(m) +- 1.1674E-02(f)
#  - etab = 5.0000E-01 +- 7.7388E-02(m) +- 5.7857E-03(f)
#  - ok = 0.0000E+00 +- 8.0020E-02(m) +- 4.7527E-04(f)
#  - wa = 0.0000E+00 +- 6.0685E-01(m) +- 5.2691E-03(f)
#  - w0 = -1.0000E+00 +- 2.0189E-01(m) +- 1.5458E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 8.1836E-02(m) +- 3.5553E-02(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 4.2966E-02(m) +- 2.2286E-02(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 6.4112E-02(m) +- 3.8513E-02(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 3.2251E-01(m) +- 1.9159E-01(f)
#  - m0 = 0.0+- 1.0089E-01(m) +- 9.5898E-02(f)
#  - m1 = 0.0+- 2.1828E-02(m) +- 1.5118E-02(f)
#  - m2 = 0.0+- 9.1022E-03(m) +- 5.0766E-03(f)
#  - m3 = 0.0+- 3.5098E-03(m) +- 2.5394E-03(f)
#  - m4 = 0.0+- 2.1875E-03(m) +- 1.6304E-03(f)
#  - m5 = 0.0+- 1.5956E-03(m) +- 1.2729E-03(f)
#  - m6 = 0.0+- 1.6221E-03(m) +- 1.1825E-03(f)
#  - m7 = 0.0+- 1.6189E-03(m) +- 1.3213E-03(f)
#  - m8 = 0.0+- 2.6631E-03(m) +- 1.7084E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0747E+00(m) +- 1.8199E-01(f)
#  - mnu = 6.0000E+01 +- 1.5738E+02(m) +- 2.6286E+00(f)
#  - och2 = 1.1970E-01 +- 3.0041E-02(m) +- 6.0082E-05(f)
#  - hh = 6.9000E-01 +- 1.0455E-01(m) +- 5.5371E-04(f)
#  - obh2 = 2.2220E-02 +- 1.0728E-02(m) +- 9.3566E-05(f)
#  - ns = 9.6550E-01 +- 4.3301E-02(m) +- 7.9607E-04(f)
#  - A_s = 2.1955E+00 +- 5.8488E-01(m) +- 2.4278E-03(f)
#  - ok = 0.0000E+00 +- 7.6542E-02(m) +- 4.7527E-04(f)
#  - wa = 0.0000E+00 +- 4.1068E-01(m) +- 5.2691E-03(f)
#  - w0 = -1.0000E+00 +- 1.8636E-01(m) +- 1.5458E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 8.0587E-02(m) +- 3.5553E-02(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 4.0456E-02(m) +- 2.2286E-02(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 6.1690E-02(m) +- 3.8513E-02(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 3.1989E-01(m) +- 1.9159E-01(f)
#  - m0 = 0.0+- 9.9690E-02(m) +- 9.5898E-02(f)
#  - m1 = 0.0+- 2.0920E-02(m) +- 1.5118E-02(f)
#  - m2 = 0.0+- 8.6818E-03(m) +- 5.0766E-03(f)
#  - m3 = 0.0+- 3.4929E-03(m) +- 2.5394E-03(f)
#  - m4 = 0.0+- 2.1841E-03(m) +- 1.6304E-03(f)
#  - m5 = 0.0+- 1.5946E-03(m) +- 1.2729E-03(f)
#  - m6 = 0.0+- 1.6210E-03(m) +- 1.1825E-03(f)
#  - m7 = 0.0+- 1.6179E-03(m) +- 1.3213E-03(f)
#  - m8 = 0.0+- 2.6515E-03(m) +- 1.7084E-03(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for abias_LSST_gold_sh_node1
# Deriv for abias_LSST_gold_sh_node2
# Deriv for abias_LSST_gold_sh_node3
# Deriv for abias_LSST_gold_sh_node4
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0875E+00(m) +- 1.8199E-01(f)
#  - mnu = 6.0000E+01 +- 2.7361E+02(m) +- 2.6286E+00(f)
#  - och2 = 1.1970E-01 +- 3.4718E-02(m) +- 6.0082E-05(f)
#  - hh = 6.9000E-01 +- 1.1592E-01(m) +- 5.5371E-04(f)
#  - obh2 = 2.2220E-02 +- 1.0358E-02(m) +- 9.3566E-05(f)
#  - ns = 9.6550E-01 +- 6.7576E-02(m) +- 7.9607E-04(f)
#  - A_s = 2.1955E+00 +- 6.2504E-01(m) +- 2.4278E-03(f)
#  - lmcb = 1.4080E+01 +- 3.4200E-01(m) +- 1.1674E-02(f)
#  - etab = 5.0000E-01 +- 7.6972E-02(m) +- 5.7857E-03(f)
#  - ok = 0.0000E+00 +- 7.6136E-02(m) +- 4.7527E-04(f)
#  - wa = 0.0000E+00 +- 5.1497E-01(m) +- 5.2691E-03(f)
#  - w0 = -1.0000E+00 +- 1.6534E-01(m) +- 1.5458E-03(f)
#  - abias_LSST_gold_sh_node1 = 1.6857E-02 +- 7.3132E-02(m) +- 3.5553E-02(f)
#  - abias_LSST_gold_sh_node2 = 4.2679E-02 +- 3.6043E-02(m) +- 2.2286E-02(f)
#  - abias_LSST_gold_sh_node3 = 3.5073E-01 +- 5.5595E-02(m) +- 3.8513E-02(f)
#  - abias_LSST_gold_sh_node4 = 7.0572E-01 +- 2.2549E-01(m) +- 1.9159E-01(f)
#
# <> Computing/reading relevant signal power spectra
# Reading fiducial
# Deriv for tau
# Deriv for mnu
# Deriv for och2
# Deriv for hh
# Deriv for obh2
# Deriv for ns
# Deriv for A_s
# Deriv for lmcb
# Deriv for etab
# Deriv for ok
# Deriv for wa
# Deriv for w0
# Deriv for m0
# Deriv for m1
# Deriv for m2
# Deriv for m3
# Deriv for m4
# Deriv for m5
# Deriv for m6
# Deriv for m7
# Deriv for m8
# <> Computing relevant noise power spectra
#    LSST_gold_sh
#
#
# Fisher forecast :
#  - tau = 6.0000E-02 +- 1.0059E+00(m) +- 1.8199E-01(f)
#  - mnu = 6.0000E+01 +- 2.6438E+02(m) +- 2.6286E+00(f)
#  - och2 = 1.1970E-01 +- 3.3086E-02(m) +- 6.0082E-05(f)
#  - hh = 6.9000E-01 +- 1.1050E-01(m) +- 5.5371E-04(f)
#  - obh2 = 2.2220E-02 +- 1.0444E-02(m) +- 9.3566E-05(f)
#  - ns = 9.6550E-01 +- 6.4499E-02(m) +- 7.9607E-04(f)
#  - A_s = 2.1955E+00 +- 5.7882E-01(m) +- 2.4278E-03(f)
#  - lmcb = 1.4080E+01 +- 3.3335E-01(m) +- 1.1674E-02(f)
#  - etab = 5.0000E-01 +- 7.4406E-02(m) +- 5.7857E-03(f)
#  - ok = 0.0000E+00 +- 7.1226E-02(m) +- 4.7527E-04(f)
#  - wa = 0.0000E+00 +- 5.3575E-01(m) +- 5.2691E-03(f)
#  - w0 = -1.0000E+00 +- 1.7642E-01(m) +- 1.5458E-03(f)
#  - m0 = 0.0+- 1.0003E-01(m) +- 9.5898E-02(f)
#  - m1 = 0.0+- 2.1323E-02(m) +- 1.5118E-02(f)
#  - m2 = 0.0+- 8.4407E-03(m) +- 5.0766E-03(f)
#  - m3 = 0.0+- 3.4737E-03(m) +- 2.5394E-03(f)
#  - m4 = 0.0+- 1.9449E-03(m) +- 1.6304E-03(f)
#  - m5 = 0.0+- 1.4838E-03(m) +- 1.2729E-03(f)
#  - m6 = 0.0+- 1.3599E-03(m) +- 1.1825E-03(f)
#  - m7 = 0.0+- 1.4807E-03(m) +- 1.3213E-03(f)
#  - m8 = 0.0+- 1.9981E-03(m) +- 1.7084E-03(f)

# %%
# Simple data to display in various forms
mnu_fid =  [60 for i in range(len(dict_test_wok))]
w0_fid =  [-1 for i in range(len(dict_test_wok))]
wa_fid =  [0 for i in range(len(dict_test_wok))]
ok_fid =  [0 for i in range(len(dict_test_wok))]


x = range(len(dict_test_wok))

mnu_sys = [dict_test_wok[i]['mnu'] for i in range(len(dict_test_wok))]
w0_sys = [dict_test_wok[i]['w0'] for i in range(len(dict_test_wok))]
wa_sys = [dict_test_wok[i]['wa'] for i in range(len(dict_test_wok))]
ok_sys = [dict_test_wok[i]['ok'] for i in range(len(dict_test_wok))]




# Three subplots sharing both x/y axes
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True, sharey=False,figsize=(7,10))
ax1.errorbar(x, mnu_fid, yerr=mnu_sys, fmt='o', capsize=10)
ax1.set_ylim(60-600,60+600)
# ax1.set_title('Systematics')
ax1.set_ylabel("$\Sigma m_\\nu$ [meV]")
ax1.axhline(60, color='cornflowerblue', lw=0.2, ls='--')
ax1.axhline(mnu_fid[0]+mnu_sys[0], color='grey', lw=0.5, ls='dotted')
ax1.axhline(mnu_fid[0]-mnu_sys[0], color='grey', lw=0.5, ls='dotted')

ax1.set_title("No CMB and clustering")

ax2.errorbar(x, w0_fid, yerr=w0_sys, fmt='o', color='firebrick', capsize=10)
ax2.set_ylim(-1-w0_sys[0]-0.2,-1+w0_sys[0]+0.2)
ax2.set_ylabel("$w_0$")
ax2.axhline(-1, color='firebrick', lw=0.2, ls='--')
ax2.axhline(w0_fid[0]+w0_sys[0], color='grey', lw=0.5, ls='dotted')
ax2.axhline(w0_fid[0]-w0_sys[0], color='grey', lw=0.5, ls='dotted')


ax3.errorbar(x, wa_fid, yerr=wa_sys, fmt='o', color='forestgreen', capsize=10)
ax3.set_ylim(0-wa_sys[0]-.4,0+wa_sys[0]+.4)
ax3.set_ylabel("$w_a$")
ax3.axhline(0, color='forestgreen', lw=0.2, ls='--')
ax3.axhline(wa_fid[0]+wa_sys[0], color='grey', lw=0.5, ls='dotted')
ax3.axhline(wa_fid[0]-wa_sys[0], color='grey', lw=0.5, ls='dotted')




ax4.errorbar(x, ok_fid, yerr=ok_sys, fmt='o', color='darkorange', capsize=10)
ax4.set_ylim(0-ok_sys[0]-0.04,ok_sys[0]+0.04)
ax4.set_ylabel("$\Omega_k$")
ax4.axhline(0, color='darkorange', lw=0.2, ls='--')
ax4.axhline(ok_fid[0]+ok_sys[0], color='grey', lw=0.5, ls='dotted')
ax4.axhline(ok_fid[0]-ok_sys[0], color='grey', lw=0.5, ls='dotted')




ax4.set_xticks(x)
ax4.set_xticklabels(yticks, rotation=45)

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f.subplots_adjust(hspace=.2)
# plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)

plt.tight_layout()
# plt.savefig(plots_dir + "systematics.pdf")
